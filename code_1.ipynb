# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
#from sklearn.metrics import classification_repo
#rt, confusion_matrix
from sklearn.model_selection import train_test_split
import string, nltk
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
df = pd.read_csv('google_reviews5.csv')
df.head()
# Out:
#                 query                   name  \
# 0  restaurant, dublin  FIRE Steakhouse & Bar
# 1  restaurant, dublin  FIRE Steakhouse & Bar
# 2  restaurant, dublin  FIRE Steakhouse & Bar
# 3  restaurant, dublin  FIRE Steakhouse & Bar
# 4  restaurant, dublin  FIRE Steakhouse & Bar
#
#                                google_id                     place_id  \
# 0  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 1  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 2  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 3  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 4  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/FIRE+Steakho...
# 1  https://www.google.com/maps/place/FIRE+Steakho...
# 2  https://www.google.com/maps/place/FIRE+Steakho...
# 3  https://www.google.com/maps/place/FIRE+Steakho...
# 4  https://www.google.com/maps/place/FIRE+Steakho...
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
# 2  https://search.google.com/local/reviews?placei...
# 3  https://search.google.com/local/reviews?placei...
# 4  https://search.google.com/local/reviews?placei...
#
#                                    reviews_per_score  reviews  rating  \
# 0  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 1  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 2  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 3  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 4  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
#
#                               review_id  ...  \
# 0   ChZDSUhNMG9nS0VJQ0FnSURScjhhVlNBEAE  ...
# 1  ChdDSUhNMG9nS0VJQ0FnSUNKdnJLY3RnRRAB  ...
# 2   ChZDSUhNMG9nS0VJQ0FnSURoczRuWU1BEAE  ...
# 3  ChdDSUhNMG9nS0VJQ0FnSUNKLXNhMnpRRRAB  ...
# 4  ChdDSUhNMG9nS0VJQ0FnSUR4OGFfVTNnRRAB  ...
#
#                                      review_img_urls owner_answer  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMWTU...          NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipMcUy...          NaN
# 2  https://lh5.googleusercontent.com/p/AF1QipMrQg...          NaN
# 3  https://lh5.googleusercontent.com/p/AF1QipOCqJ...          NaN
# 4  https://lh5.googleusercontent.com/p/AF1QipP7KU...          NaN
#
#    owner_answer_timestamp owner_answer_timestamp_datetime_utc  \
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
# 2                     NaN                                 NaN
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
#                                          review_link review_rating  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 1  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 2  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 3  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 4  https://www.google.com/maps/reviews/data=!4m8!...           5.0
#
#   review_timestamp  review_datetime_utc  review_likes    reviews_id
# 0     1.683401e+09     05/06/2023 19:20           0.0 -6.373780e+18
# 1     1.687931e+09  06/28/2023 05:41:44           1.0 -6.373780e+18
# 2     1.679049e+09  03/17/2023 10:27:11           1.0 -6.373780e+18
# 3     1.687723e+09  06/25/2023 19:54:18           0.0 -6.373780e+18
# 4     1.686415e+09     06/10/2023 16:43           0.0 -6.373780e+18
#
# [5 rows x 26 columns]

# %%
print (df['rating'].unique())
# Out:
# [4.4 4.1 4.2 3.9 4.5 4.6 4.3 4.7 4.8]

# %%
#EDA
df.isnull().sum()
# Out:
# query                                    0
# name                                     0
# google_id                                0
# place_id                                 0
# location_link                            0
# reviews_link                             0
# reviews_per_score                        0
# reviews                                  0
# rating                                   0
# review_id                                0
# author_link                              0
# author_title                             0
# author_id                                0
# author_image                             0
# review_text                              0
# review_img_url                         257
# review_img_urls                        257
# owner_answer                           828
# owner_answer_timestamp                 829
# owner_answer_timestamp_datetime_utc    829
# review_link                              1
# review_rating                            1
# review_timestamp                         1
# review_datetime_utc                      1
# review_likes                             1
# reviews_id                               1
# dtype: int64

# %%
df['review_text']. dropna() #need to deal with missing data-delete rows?, justify. empty reviews dropped, not useful to dataset
# Out:
# 0      This place is absolutely outstanding. It was a...
# 1      Excellent dinner experience in the city center...
# 2      Outstanding from start to finish!\n\nEnjoyed a...
# 3      Called in on a Saturday without a booking with...
# 4      We went today for lunch, food was amazing! The...
#                              ...
# 995    First time visiting and it was an excellent ex...
# 996    Mr. Fox have been the best choice that I made ...
# 997    Words cannot describe the impeccable experienc...
# 998    That was a first restaurant we went after a lo...
# 999          Lovely place!  Very private and great food!
# Name: review_text, Length: 1000, dtype: object

# %%
df=df.dropna(subset=['review_text'])

# %%
df.isnull().sum()
# Out:
# query                                    0
# name                                     0
# google_id                                0
# place_id                                 0
# location_link                            0
# reviews_link                             0
# reviews_per_score                        0
# reviews                                  0
# rating                                   0
# review_id                                0
# author_link                              0
# author_title                             0
# author_id                                0
# author_image                             0
# review_text                              0
# review_img_url                         257
# review_img_urls                        257
# owner_answer                           828
# owner_answer_timestamp                 829
# owner_answer_timestamp_datetime_utc    829
# review_link                              1
# review_rating                            1
# review_timestamp                         1
# review_datetime_utc                      1
# review_likes                             1
# reviews_id                               1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   query                                1000 non-null   object
#  1   name                                 1000 non-null   object
#  2   google_id                            1000 non-null   object
#  3   place_id                             1000 non-null   object
#  4   location_link                        1000 non-null   object
#  5   reviews_link                         1000 non-null   object
#  6   reviews_per_score                    1000 non-null   object
#  7   reviews                              1000 non-null   int64
#  8   rating                               1000 non-null   float64
#  9   review_id                            1000 non-null   object
#  10  author_link                          1000 non-null   object
#  11  author_title                         1000 non-null   object
#  12  author_id                            1000 non-null   float64
#  13  author_image                         1000 non-null   object
#  14  review_text                          1000 non-null   object
#  15  review_img_url                       743 non-null    object
#  16  review_img_urls                      743 non-null    object
#  17  owner_answer                         172 non-null    object
#  18  owner_answer_timestamp               171 non-null    float64
#  19  owner_answer_timestamp_datetime_utc  171 non-null    object
#  20  review_link                          999 non-null    object
#  21  review_rating                        999 non-null    float64
#  22  review_timestamp                     999 non-null    float64
#  23  review_datetime_utc                  999 non-null    object
#  24  review_likes                         999 non-null    float64
#  25  reviews_id                           999 non-null    float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 203.2+ KB

# %%
df.describe()
# Out:
#             reviews       rating     author_id  owner_answer_timestamp  \
# count   1000.000000  1000.000000  1.000000e+03            1.710000e+02
# mean    2680.000000     4.370000  1.094714e+20            1.674750e+09
# std     2507.339277     0.243227  5.398746e+18            1.352623e+07
# min      845.000000     3.900000  1.000010e+20            1.626207e+09
# 25%     1575.250000     4.175000  1.047080e+20            1.670256e+09
# 50%     2088.000000     4.400000  1.096475e+20            1.679905e+09
# 75%     2998.500000     4.525000  1.142652e+20            1.683452e+09
# max    12985.000000     4.800000  1.184240e+20            1.688986e+09
#
#        review_rating  review_timestamp  review_likes    reviews_id
# count     999.000000      9.990000e+02    999.000000  9.990000e+02
# mean        4.361361      1.668195e+09      0.766767  2.886360e+17
# std         1.078366      3.211613e+07      1.522923  5.136254e+18
# min         1.000000      1.486412e+09      0.000000 -9.131130e+18
# 25%         4.000000      1.666274e+09      0.000000 -4.257645e+18
# 50%         5.000000      1.678917e+09      0.000000  7.085230e+17
# 75%         5.000000      1.684693e+09      1.000000  4.049010e+18
# max         5.000000      1.689081e+09     17.000000  8.981480e+18

# %%
df.shape
# Out:
# (1000, 26)

# %%
df['rating'].value_counts()
# Out:
# 4.4    200
# 4.1    200
# 4.7    150
# 4.2    100
# 4.5    100
# 4.3    100
# 3.9     50
# 4.6     50
# 4.8     50
# Name: rating, dtype: int64

# %%
plt.figure(figsize=(15,8))
labels = df['rating'].value_counts().keys()
values = df['rating'].value_counts().values
explode = (0.1,0,0,0,0)
plt.pie(values,labels=labels,explode=explode,shadow=True,autopct='%1.1f%%')
plt.title('Proportion of each rating',fontweight='bold',fontsize=25,pad=20,color='crimson')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 5
#       3 values = df['rating'].value_counts().values
#       4 explode = (0.1,0,0,0,0)
# ----> 5 plt.pie(values,labels=labels,explode=explode,shadow=True,autopct='%1.1f%%')
#       6 plt.title('Proportion of each rating',fontweight='bold',fontsize=25,pad=20,color='crimson')
#       7 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2772, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2765 @_copy_docstring_and_deprecators(Axes.pie)
#    2766 def pie(
#    2767         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2770         textprops=None, center=(0, 0), frame=False,
#    2771         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2772     return gca().pie(
#    2773         x, explode=explode, labels=labels, colors=colors,
#    2774         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2775         labeldistance=labeldistance, startangle=startangle,
#    2776         radius=radius, counterclock=counterclock,
#    2777         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2778         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2779         hatch=hatch, **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3211, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3209     raise ValueError("'label' must be of length 'x'")
#    3210 if len(x) != len(explode):
# -> 3211     raise ValueError("'explode' must be of length 'x'")
#    3212 if colors is None:
#    3213     get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x'

# %%
import string

def clean_text(text):
    nopunc = [w for w in text if w not in string.punctuation]
    nopunc = ''.join(nopunc)
    return  ' '.join([word for word in nopunc.split() if word.lower()])

# %%
df.review_text.astype(str)
# Out:
# 0      This place is absolutely outstanding. It was a...
# 1      Excellent dinner experience in the city center...
# 2      Outstanding from start to finish!\n\nEnjoyed a...
# 3      Called in on a Saturday without a booking with...
# 4      We went today for lunch, food was amazing! The...
#                              ...
# 995    First time visiting and it was an excellent ex...
# 996    Mr. Fox have been the best choice that I made ...
# 997    Words cannot describe the impeccable experienc...
# 998    That was a first restaurant we went after a lo...
# 999          Lovely place!  Very private and great food!
# Name: review_text, Length: 1000, dtype: object

# %%
#pip install WordCloud

# %%
#Creating Stopwords list
from wordcloud import WordCloud
from nltk.corpus import stopwords

stopwords=set(stopwords.words('english'))
stopwords.update(["br","href", "good",'Translated' 'by' 'Google','of','the','is'])
textt = " ".join(review for review in df.review_text)
wordcloud = WordCloud(stopwords=stopwords).generate(textt)


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df['review_text'].head().apply(clean_text)
# Out:
# 0    This place is absolutely outstanding It was a ...
# 1    Excellent dinner experience in the city center...
# 2    Outstanding from start to finish Enjoyed a won...
# 3    Called in on a Saturday without a booking with...
# 4    We went today for lunch food was amazing The p...
# Name: review_text, dtype: object

# %%
df.loc[0, 'review_text'][-50:]
# Out:
# "dn't suit a standard date night (for most people)."

# %%
#counting nr. of stopwords per review
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
df['nr_stopwords'] = df['review_text'].apply(lambda x: len(set(x.split()) & stop_words))

# %%
df['nr_stopwords'].describe()#assessing nr. of stopwords in dataset
# Out:
# count    1000.000000
# mean       15.025000
# std         8.637533
# min         0.000000
# 25%         9.000000
# 50%        13.000000
# 75%        20.000000
# max        54.000000
# Name: nr_stopwords, dtype: float64

# %%
import string 
# Storing the sets of punctuation in variable result 
result = string.punctuation 
print(result)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
from collections import Counter
count = lambda l1,l2: sum([1 for x in l1 if x in l2])

df['count_punct'] = df.review_text.apply(lambda s: count(s, string.punctuation))
accumulate = lambda l1,l2: [x for x in l1 if x in l2]

df['acc_punct_list'] = df.review_text.apply(lambda s: accumulate(s, string.punctuation))
# accumulate the punctuation marks of each line in a dict and transpose each element into dataframe columns
df['acc_punct_dict'] = df.review_text.apply(lambda s: {k: v for k, v in Counter(s).items() if k in string.punctuation} if any(char in string.punctuation for char in s) else {})

# %%
df_punct = df.acc_punct_dict.apply(pd.Series)

# %%
df_punct
# Out:
#        .    ,    '    (    )    !    :   -   +   ;   /   &   "   %   *   #  \
# 0    6.0  4.0  1.0  1.0  1.0  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1    4.0  NaN  NaN  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2    6.0  NaN  NaN  1.0  1.0  6.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3    5.0  NaN  NaN  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4    1.0  4.0  NaN  1.0  1.0  1.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# ..   ...  ...  ...  ...  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 995  2.0  1.0  NaN  NaN  NaN  1.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 996  7.0  4.0  NaN  NaN  NaN  1.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 997  1.0  2.0  NaN  NaN  NaN  2.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 998  4.0  NaN  1.0  NaN  NaN  NaN  2.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 999  NaN  NaN  NaN  NaN  NaN  2.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
#       ?   ~   @   \
# 0   NaN NaN NaN NaN
# 1   NaN NaN NaN NaN
# 2   NaN NaN NaN NaN
# 3   NaN NaN NaN NaN
# 4   NaN NaN NaN NaN
# ..   ..  ..  ..  ..
# 995 NaN NaN NaN NaN
# 996 NaN NaN NaN NaN
# 997 NaN NaN NaN NaN
# 998 NaN NaN NaN NaN
# 999 NaN NaN NaN NaN
#
# [1000 rows x 20 columns]

# %%
df.head()
# Out:
#                 query                   name  \
# 0  restaurant, dublin  FIRE Steakhouse & Bar
# 1  restaurant, dublin  FIRE Steakhouse & Bar
# 2  restaurant, dublin  FIRE Steakhouse & Bar
# 3  restaurant, dublin  FIRE Steakhouse & Bar
# 4  restaurant, dublin  FIRE Steakhouse & Bar
#
#                                google_id                     place_id  \
# 0  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 1  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 2  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 3  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 4  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/FIRE+Steakho...
# 1  https://www.google.com/maps/place/FIRE+Steakho...
# 2  https://www.google.com/maps/place/FIRE+Steakho...
# 3  https://www.google.com/maps/place/FIRE+Steakho...
# 4  https://www.google.com/maps/place/FIRE+Steakho...
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
# 2  https://search.google.com/local/reviews?placei...
# 3  https://search.google.com/local/reviews?placei...
# 4  https://search.google.com/local/reviews?placei...
#
#                                    reviews_per_score  reviews  rating  \
# 0  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 1  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 2  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 3  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 4  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
#
#                               review_id  ...  \
# 0   ChZDSUhNMG9nS0VJQ0FnSURScjhhVlNBEAE  ...
# 1  ChdDSUhNMG9nS0VJQ0FnSUNKdnJLY3RnRRAB  ...
# 2   ChZDSUhNMG9nS0VJQ0FnSURoczRuWU1BEAE  ...
# 3  ChdDSUhNMG9nS0VJQ0FnSUNKLXNhMnpRRRAB  ...
# 4  ChdDSUhNMG9nS0VJQ0FnSUR4OGFfVTNnRRAB  ...
#
#   owner_answer_timestamp_datetime_utc  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                          review_link  review_rating  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...            5.0
# 1  https://www.google.com/maps/reviews/data=!4m8!...            5.0
# 2  https://www.google.com/maps/reviews/data=!4m8!...            5.0
# 3  https://www.google.com/maps/reviews/data=!4m8!...            5.0
# 4  https://www.google.com/maps/reviews/data=!4m8!...            5.0
#
#   review_timestamp  review_datetime_utc review_likes    reviews_id  \
# 0     1.683401e+09     05/06/2023 19:20          0.0 -6.373780e+18
# 1     1.687931e+09  06/28/2023 05:41:44          1.0 -6.373780e+18
# 2     1.679049e+09  03/17/2023 10:27:11          1.0 -6.373780e+18
# 3     1.687723e+09  06/25/2023 19:54:18          0.0 -6.373780e+18
# 4     1.686415e+09     06/10/2023 16:43          0.0 -6.373780e+18
#
#   count_punct                              acc_punct_list  \
# 0          13     [., ., ,, ., ,, ., ,, ., ,, ', (, ), .]
# 1           4                                [., ., ., .]
# 2          14  [!, ., ., ., ., (, ), !, !, !, ., ., !, !]
# 3           5                             [., ., ., ., .]
# 4           8                    [,, !, ., (, ), ,, ,, ,]
#
#                              acc_punct_dict
# 0  {'.': 6, ',': 4, ''': 1, '(': 1, ')': 1}
# 1                                  {'.': 4}
# 2          {'!': 6, '.': 6, '(': 1, ')': 1}
# 3                                  {'.': 5}
# 4  {',': 4, '!': 1, '.': 1, '(': 1, ')': 1}
#
# [5 rows x 29 columns]

# %%
import nltk
nltk.download('brown')
from nltk.corpus import brown
from nltk.tag import pos_tag_sents#importing tagger for POS speech tagging
brown.words()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
df['tokenized_review'] = df.apply(lambda row: nltk.word_tokenize(row['review_text']), axis=1)
df['review_length'] = df.apply(lambda row: len(row['tokenized_review']), axis=1)
df.head()
#https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da
#count nr. of adjectives and nouns in review
# Out:
#                 query                   name  \
# 0  restaurant, dublin  FIRE Steakhouse & Bar
# 1  restaurant, dublin  FIRE Steakhouse & Bar
# 2  restaurant, dublin  FIRE Steakhouse & Bar
# 3  restaurant, dublin  FIRE Steakhouse & Bar
# 4  restaurant, dublin  FIRE Steakhouse & Bar
#
#                                google_id                     place_id  \
# 0  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 1  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 2  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 3  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 4  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/FIRE+Steakho...
# 1  https://www.google.com/maps/place/FIRE+Steakho...
# 2  https://www.google.com/maps/place/FIRE+Steakho...
# 3  https://www.google.com/maps/place/FIRE+Steakho...
# 4  https://www.google.com/maps/place/FIRE+Steakho...
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
# 2  https://search.google.com/local/reviews?placei...
# 3  https://search.google.com/local/reviews?placei...
# 4  https://search.google.com/local/reviews?placei...
#
#                                    reviews_per_score  reviews  rating  \
# 0  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 1  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 2  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 3  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 4  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
#
#                               review_id  ... review_rating review_timestamp  \
# 0   ChZDSUhNMG9nS0VJQ0FnSURScjhhVlNBEAE  ...           5.0     1.683401e+09
# 1  ChdDSUhNMG9nS0VJQ0FnSUNKdnJLY3RnRRAB  ...           5.0     1.687931e+09
# 2   ChZDSUhNMG9nS0VJQ0FnSURoczRuWU1BEAE  ...           5.0     1.679049e+09
# 3  ChdDSUhNMG9nS0VJQ0FnSUNKLXNhMnpRRRAB  ...           5.0     1.687723e+09
# 4  ChdDSUhNMG9nS0VJQ0FnSUR4OGFfVTNnRRAB  ...           5.0     1.686415e+09
#
#    review_datetime_utc review_likes    reviews_id count_punct  \
# 0     05/06/2023 19:20          0.0 -6.373780e+18          13
# 1  06/28/2023 05:41:44          1.0 -6.373780e+18           4
# 2  03/17/2023 10:27:11          1.0 -6.373780e+18          14
# 3  06/25/2023 19:54:18          0.0 -6.373780e+18           5
# 4     06/10/2023 16:43          0.0 -6.373780e+18           8
#
#                                acc_punct_list  \
# 0     [., ., ,, ., ,, ., ,, ., ,, ', (, ), .]
# 1                                [., ., ., .]
# 2  [!, ., ., ., ., (, ), !, !, !, ., ., !, !]
# 3                             [., ., ., ., .]
# 4                    [,, !, ., (, ), ,, ,, ,]
#
#                              acc_punct_dict  \
# 0  {'.': 6, ',': 4, ''': 1, '(': 1, ')': 1}
# 1                                  {'.': 4}
# 2          {'!': 6, '.': 6, '(': 1, ')': 1}
# 3                                  {'.': 5}
# 4  {',': 4, '!': 1, '.': 1, '(': 1, ')': 1}
#
#                                     tokenized_review review_length
# 0  [This, place, is, absolutely, outstanding, ., ...           116
# 1  [Excellent, dinner, experience, in, the, city,...            52
# 2  [Outstanding, from, start, to, finish, !, Enjo...           134
# 3  [Called, in, on, a, Saturday, without, a, book...            79
# 4  [We, went, today, for, lunch, ,, food, was, am...            61
#
# [5 rows x 31 columns]

# %%
#pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.6.0-cp310-cp310-win_amd64.whl (12.3 MB)
#      ---------------------------------------- 12.3/12.3 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\quain\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.9/45.9 kB 2.2 MB/s eta 0:00:00
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.10-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\quain\anaconda3\lib\site-packages (from spacy) (22.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.11-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.0 in c:\users\quain\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-win_amd64.whl (18 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.7-cp310-cp310-win_amd64.whl (481 kB)
#      ------------------------------------- 481.6/481.6 kB 15.2 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-win_amd64.whl (94 kB)
#      ---------------------------------------- 94.7/94.7 kB 5.3 MB/s eta 0:00:00
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.9/48.9 kB 2.6 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\quain\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-win_amd64.whl (29 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ------------------------------------- 181.6/181.6 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\quain\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\quain\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\quain\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\quain\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\quain\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\quain\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\quain\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\quain\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.0-py3-none-any.whl (34 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.10-cp310-cp310-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\quain\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\quain\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\quain\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, pydantic, murmurhash, langcodes, catalogue, blis, typer, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.10 catalogue-2.0.8 confection-0.1.0 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.2 preshed-3.0.8 pydantic-1.10.11 spacy-3.6.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.7 thinc-8.1.10 typer-0.9.0 wasabi-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm -q
# Out:
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
from collections import Counter
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
from spacy.lang.en.examples import sentences 

nlp = spacy.load("en_core_web_sm")
import en_core_web_sm

# %%
df['review_text'].astype(str)
doc = df['review_text'].apply(nlp)#applying spacy and background pipeline will return the objects.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[109], line 6
#       4 doc = df['review_text'].apply(nlp)
#       5 # Print named entities and their labels for each text
# ----> 6 pprint([(X.text, X.label_) for X in doc.ents])
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'ents'

# %%
# Function to process each text and extract named entities
def get_named_entities(text):
    doc = nlp(text)
    return [(X.text, X.label_) for X in doc.ents]

# Apply the function to 'review_text' column and store the results in a new column 'named_entities'
df['named_entities'] = df['review_text'].apply(get_named_entities)
#reate a function get_named_entities that processes each text using spaCy and returns a
#list of named entities and their labels. Then, we use the apply method to apply this function 
#to each element in the 'review_text' column and store the results in a new column called 'named_entities'.
#Now, you can access the named entities for each text in the DataFrame.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 8
#       6 # Apply the function to 'review_text' column and store the results in a new column 'named_entities'
#       7 df['named_entities'] = df['review_text'].apply(get_named_entities)
# ----> 8 pprint([(X.text, X.label_) for X in doc.ents])
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'ents'

# %%
print(df['named_entities'].head())
# Out:
# 0                                                   []
# 1                   [(Dublin, GPE), (three, CARDINAL)]
# 2    [(Fire.\n\n, FAC), (3, CARDINAL), (Two, CARDIN...
# 3                                   [(Saturday, DATE)]
# 4       [(today, DATE), (Alex, PERSON), (Greece, GPE)]
# Name: named_entities, dtype: object

# %%
displacy.render(nlp(str(df['named_entities'])), jupyter=True, style='ent')
#generate the raw markup.
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">0                                                     []</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# [(
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dublin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GPE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CARDINAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# )]</br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# [(
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fire.\n\n, FAC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CARDINAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , CARDIN...</br>3                                     [(
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , DATE)]</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# [(
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , DATE), (Alex, PERSON), (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Greece
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GPE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# )]</br>                             ...                        </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     995
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# [(
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ORDINAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), (over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TIME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# )]</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     996
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#                        [(
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fox
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , PERSON), (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fox
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , PERSON)]</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     997
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#                            [(
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Truly Michelin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left:

# %%
displacy.render(nlp(str(df['named_entities'])), style='dep', jupyter = True, options = {'distance': 120})
#Using spaCy’s built-in displaCy visualizer, here’s what the above sentence and its dependencies look like
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2bc4780fc4f64d15bb0829368e3efb34-0" class="displacy" width="8930" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">0</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">                                                    []</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">                    [(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Dublin,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">GPE), (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">three,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">CARDINAL)]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">     [(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Fire.\n\n,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">FAC), (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">3,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">CARDINAL), (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Two,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">CARDIN...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">                                    [(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Saturday,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">DATE)]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">        [(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">today,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">DATE), (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">Alex,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">PERSON), (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan cl

# %%
# extract part-of-speech and lemmatize
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(df['named_entities'])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('0', 'NUM', '0'),
#  ('                                                    ',
#   'SPACE',
#   '                                                    '),
#  ('[', 'X', '['),
#  (']', 'X', ']'),
#  ('\n', 'SPACE', '\n'),
#  ('1', 'NUM', '1'),
#  ('                    ', 'SPACE', '                    '),
#  ('[', 'X', '['),
#  ('Dublin', 'PROPN', 'Dublin'),
#  ('GPE', 'PROPN', 'GPE'),
#  ('CARDINAL', 'PROPN', 'CARDINAL'),
#  ('\n', 'SPACE', '\n'),
#  ('2', 'NUM', '2'),
#  ('     ', 'SPACE', '     '),
#  ('Fire.\\n\\n', 'PROPN', 'Fire.\\n\\n'),
#  ('FAC', 'PROPN', 'FAC'),
#  ('3', 'NUM', '3'),
#  ('CARDINAL', 'PROPN', 'CARDINAL'),
#  ('CARDIN', 'PROPN', 'CARDIN'),
#  ('\n', 'SPACE', '\n'),
#  ('3', 'NUM', '3'),
#  ('                                    ',
#   'SPACE',
#   '                                    '),
#  ('[', 'X', '['),
#  ('Saturday', 'PROPN', 'Saturday'),
#  ('DATE', 'PROPN', 'DATE'),
#  ('\n', 'SPACE', '\n'),
#  ('4', 'NUM', '4'),
#  ('        ', 'SPACE', '        '),
#  ('today', 'NOUN', 'today'),
#  ('DATE', 'NOUN', 'date'),
#  ('Alex', 'PROPN', 'Alex'),
#  ('PERSON', 'PROPN', 'PERSON'),
#  ('Greece', 'PROPN', 'Greece'),
#  ('GPE', 'PROPN', 'GPE'),
#  ('\n                             ',
#   'SPACE',
#   '\n                             '),
#  ('                       \n', 'SPACE', '                       \n'),
#  ('995', 'NUM', '995'),
#  ('            ', 'SPACE', '            '),
#  ('[', 'X', '['),
#  ('ORDINAL', 'PROPN', 'ORDINAL'),
#  ('2', 'NUM', '2'),
#  ('hours', 'NOUN', 'hour'),
#  ('TIME', 'PROPN', 'TIME'),
#  ('\n', 'SPACE', '\n'),
#  ('996', 'NUM', '996'),
#  ('                      ', 'SPACE', '                      '),
#  ('[', 'X', '['),
#  ('Fox', 'PROPN', 'Fox'),
#  ('PERSON', 'PROPN', 'PERSON'),
#  ('Fox', 'PROPN', 'Fox'),
#  ('PERSON', 'PROPN', 'PERSON'),
#  ('\n', 'SPACE', '\n'),
#  ('997', 'NUM', '997'),
#  ('                          ', 'SPACE', '                          '),
#  ('Truly', 'ADV', 'truly'),
#  ('Michelin', 'PROPN', 'Michelin'),
#  ('PERSON', 'PROPN', 'PERSON'),
#  ('\n', 'SPACE', '\n'),
#  ('998', 'NUM', '998'),
#  ('   ', 'SPACE', '   '),
#  ('ORDINAL', 'PROPN', 'ORDINAL'),
#  ('Ireland', 'PROPN', 'Ireland'),
#  ('GPE', 'PROPN', 'GPE'),
#  ('11', 'NUM', '11'),
#  ('CARDIN', 'PROPN', 'CARDIN'),
#  ('\n', 'SPACE', '\n'),
#  ('999', 'NUM', '999'),
#  ('                                                  ',
#   'SPACE',
#   '                                                  '),
#  ('[', 'X', '['),
#  (']', 'X', ']'),
#  ('\n', 'SPACE', '\n'),
#  ('named_entities', 'NOUN', 'named_entitie'),
#  ('Length', 'PROPN', 'Length'),
#  ('1000', 'NUM', '1000'),
#  ('dtype', 'VERB', 'dtype'),
#  ('object', 'NOUN', 'object')]

# %%
dict([(str(x), x.label_) for x in nlp(str(df['named_entities'])).ents])
#using a list comprehension to extract token information (orthographic 
#representation, part-of-speech tag, and lemma) from a spaCy Doc object
#output is a list of tuples, each containing the orthographic representation,
#part-of-speech tag, and lemma of the tokens
# Out:
# {'1                     ': 'CARDINAL',
#  'Dublin': 'GPE',
#  'GPE': 'ORG',
#  'three': 'CARDINAL',
#  'CARDINAL': 'ORG',
#  '2      ': 'PRODUCT',
#  'Fire.\\n\\n, FAC': 'ORG',
#  '3': 'CARDINAL',
#  'Two': 'CARDINAL',
#  'Saturday': 'DATE',
#  '4         ': 'CARDINAL',
#  'today': 'DATE',
#  'Greece': 'GPE',
#  '995             ': 'CARDINAL',
#  'First': 'ORDINAL',
#  'ORDINAL': 'ORG',
#  '2 hours': 'TIME',
#  'TIME': 'ORG',
#  '996': 'CARDINAL',
#  'Fox': 'ORG',
#  '997': 'CARDINAL',
#  'Truly Michelin': 'PERSON',
#  '998': 'CARDINAL',
#  'first': 'ORDINAL',
#  'Ireland': 'GPE',
#  '11': 'CARDINAL',
#  '999                                                   ': 'CARDINAL',
#  'Length': 'PERSON',
#  '1000': 'CARDINAL'}

# %%
for entities in df['named_entities']:
    print(entities)
# Out:
# []
# [('Dublin', 'GPE'), ('three', 'CARDINAL')]
# [('Fire.\n\n', 'FAC'), ('3', 'CARDINAL'), ('Two', 'CARDINAL'), ('Dawson St', 'PERSON'), ('evening', 'TIME')]
# [('Saturday', 'DATE')]
# [('today', 'DATE'), ('Alex', 'PERSON'), ('Greece', 'GPE')]
# [('the end of the night', 'DATE'), ('two', 'CARDINAL'), ('two', 'CARDINAL')]
# [('Leonardo Bueno', 'PERSON'), ('dessert', 'PERSON'), ('the lemmon sorbet', 'PERSON'), ('irish', 'NORP'), ('about a day', 'DATE'), ('Dublin', 'GPE')]
# [('this evening', 'TIME'), ('this evening', 'TIME'), ('17:30', 'TIME')]
# [('Level', 'PERSON'), ('Dublin', 'GPE'), ('6', 'CARDINAL'), ('Saturday', 'DATE'), ('40€', 'QUANTITY'), ('3', 'CARDINAL'), ('the Rib Eye', 'ORG')]
# [('Thursday', 'DATE'), ('the day before', 'DATE'), ('3', 'CARDINAL'), ('Connemara', 'GPE'), ('Irish', 'NORP'), ('Mango Caipirinha', 'PERSON'), ('Grafton', 'ORG'), ("St. Stephen's Green", 'GPE')]
# [('dublin', 'GPE'), ('2', 'CARDINAL'), ('60 euro', 'QUANTITY'), ('3', 'CARDINAL'), ('🍞', 'ORG'), ('2', 'CARDINAL'), ('14', 'CARDINAL'), ('💺', 'ORG'), ('2', 'CARDINAL'), ('35 euro', 'QUANTITY'), ('2', 'CARDINAL'), ('40 euro', 'QUANTITY'), ('3', 'CARDINAL'), ('dublin', 'GPE')]
# [('Monday', 'DATE'), ('first', 'ORDINAL')]
# []
# [('Interior', 'ORG')]
# [('Dublin', 'GPE'), ('three', 'CARDINAL')]
# []
# [('years', 'DATE'), ('Danielle', 'GPE'), ('Maria', 'PERSON')]
# []
# [('spanish', 'NORP')]
# []
# [('last night', 'TIME'), ('12', 'CARDINAL'), ('less than 5 minutes', 'TIME'), ('the night', 'TIME'), ('2', 'CARDINAL'), ('our evening', 'TIME')]
# []
# [('night', 'TIME')]
# [('our day', 'DATE'), ('evening', 'TIME')]
# [('2 year', 'DATE'), ('our night', 'TIME')]
# []
# [('One', 'CARDINAL'), ('dessert xD', 'PERSON')]
# [('Dublin', 'GPE'), ('Christmas', 'DATE'), ('3', 'CARDINAL'), ('52', 'MONEY')]
# [('Christmas', 'DATE'), ('Waiter', 'PERSON'), ('About 100', 'CARDINAL'), ('Christmas', 'DATE')]
# []
# [('mans', 'NORP'), ('Christmas 3', 'DATE'), ('the Butternut Squash Soup 9/10', 'ORG'), ('Turkey', 'GPE'), ('Gateaux', 'PERSON'), ('8/10', 'CARDINAL'), ('Gateaux', 'PERSON')]
# []
# [('Hereford', 'WORK_OF_ART')]
# [('5.50', 'MONEY'), ('4', 'CARDINAL'), ('6', 'CARDINAL'), ('225', 'MONEY')]
# [('weeks', 'DATE'), ('12', 'CARDINAL'), ('First', 'ORDINAL'), ('12', 'CARDINAL'), ('8', 'CARDINAL'), ('60 euro', 'QUANTITY'), ('Mexican', 'NORP'), ('3', 'CARDINAL'), ('5', 'CARDINAL'), ('One', 'CARDINAL')]
# [('One', 'CARDINAL'), ('Dublin', 'GPE'), ('50', 'CARDINAL'), ('one', 'CARDINAL'), ('2', 'CARDINAL')]
# [('4/5', 'CARDINAL'), ('3/5', 'CARDINAL'), ('2/5', 'CARDINAL'), ('Vegan', 'ORG'), ('1/5', 'CARDINAL'), ('3/5', 'CARDINAL'), ('4/5', 'CARDINAL')]
# [('First', 'ORDINAL'), ('second', 'ORDINAL'), ('Chile', 'GPE'), ('Dawson', 'GPE'), ('🥩', 'CARDINAL'), ('DM', 'GPE'), ('Insta', 'ORG')]
# []
# [('Soso', 'PERSON')]
# [('17', 'CARDINAL'), ('2', 'CARDINAL')]
# [('one', 'CARDINAL')]
# [('first', 'ORDINAL'), ('Saturday', 'DATE'), ('afternoon', 'TIME'), ('Cloudy Bay', 'LOC')]
# [('2nd Christmas Dinner', 'DATE'), ('December', 'DATE'), ('Christmas', 'DATE')]
# [('2', 'CARDINAL'), ('2', 'CARDINAL'), ('that day', 'DATE'), ('jean', 'NORP')]
# [('years', 'DATE'), ('6', 'CARDINAL')]
# [('3/5', 'CARDINAL')]
# []
# [('fresh🦪', 'ORG')]
# [('Danielle', 'GPE'), ('Sirloin', 'PERSON')]
# [('10', 'CARDINAL'), ('10', 'CARDINAL'), ('4', 'CARDINAL')]
# [('Nolita', 'PERSON'), ('10pm', 'TIME')]
# [('the Spanish Harlem', 'ORG')]
# [('the night', 'TIME'), ('Dublin', 'GPE')]
# [('Stylish', 'NORP')]
# []
# [('13', 'CARDINAL'), ('around 11', 'CARDINAL'), ('12', 'CARDINAL'), ('10', 'CARDINAL')]
# []
# []
# []
# [('first', 'ORDINAL'), ('Yhaz', 'PERSON'), ('Atmosphere', 'PERSON')]
# [('2000', 'DATE'), ('five', 'CARDINAL'), ('the day', 'DATE')]
# [('italian', 'NORP')]
# []
# [('5', 'CARDINAL')]
# [('appetizer &', 'ORG'), ('at least 5+ minutes', 'DATE'), ('Secondly', 'ORDINAL'), ('second', 'ORDINAL'), ('décor & interior', 'ORG')]
# [('Saturday', 'DATE'), ('20', 'CARDINAL'), ('One', 'CARDINAL'), ('one', 'CARDINAL'), ('29', 'MONEY')]
# []
# [('Juan', 'PERSON'), ('12', 'CARDINAL'), ('Juan', 'PERSON')]
# [('more than 15', 'CARDINAL'), ('5', 'CARDINAL'), ('the day', 'DATE')]
# [('100%', 'PERCENT')]
# [('Last night', 'TIME'), ('32nd', 'ORDINAL'), ('last night', 'TIME'), ('God', 'PERSON'), ('🙏', 'ORG'), ('Nolita', 'PERSON'), ('Nolita', 'PERSON')]
# [('Two', 'CARDINAL')]
# [('6', 'CARDINAL'), ('the span of an hour', 'DATE'), ('Asians', 'NORP')]
# [('7.30', 'CARDINAL')]
# []
# [('today 14/05/2023', 'DATE'), ('2', 'CARDINAL'), ('Luciano', 'PERSON')]
# [('Dublin', 'GPE'), ('Nolita Bar', 'PERSON'), ('Nolita Bar', 'PERSON'), ('Nolita', 'ORG'), ('Nolita', 'PERSON'), ('One', 'CARDINAL'), ('Nolita Bar', 'PERSON'), ('Nolita Bar', 'PERSON'), ('Nolita', 'ORG'), ('Nolita Bar', 'ORG'), ('nights', 'TIME'), ('Nolita', 'PERSON'), ('a night', 'TIME'), ('Nolita Bar', 'PERSON'), ('peak hours', 'TIME'), ('Nolita Bar', 'PERSON'), ('Dublin', 'GPE'), ('stylish decor', 'PERSON'), ('a night', 'TIME'), ('Nolita Bar', 'PERSON'), ('night', 'TIME')]
# [('Risotto', 'PERSON')]
# [('today', 'DATE'), ('Aaron', 'PERSON'), ('100%', 'PERCENT')]
# [('John', 'PERSON'), ('broccoli', 'GPE'), ('Parmesan', 'PERSON'), ('the weekend', 'DATE'), ('John', 'PERSON'), ('nights', 'TIME'), ('two', 'CARDINAL')]
# [('Dublin', 'GPE'), ('10€', 'QUANTITY'), ('5', 'CARDINAL')]
# []
# [('dessert', 'PERSON'), ('Guinness', 'ORG')]
# [('20 euro', 'QUANTITY')]
# [('First', 'ORDINAL'), ('Dublin', 'GPE'), ('2', 'CARDINAL'), ('2 minutes', 'TIME')]
# [('the day', 'DATE'), ('Venue 10/10', 'FAC'), ('this days', 'DATE'), ('John', 'PERSON'), ('midnight', 'TIME')]
# [('almost an hour', 'TIME')]
# [('1 minute', 'TIME'), ('5 minutes later', 'TIME'), ('first', 'ORDINAL')]
# []
# [('just over half', 'CARDINAL'), ('13', 'CARDINAL')]
# [('John', 'PERSON')]
# [('Nolita', 'PERSON'), ('Thursday', 'DATE'), ('evening', 'TIME'), ('night', 'TIME'), ('One', 'CARDINAL')]
# [('first', 'ORDINAL'), ('first', 'ORDINAL')]
# [('night', 'TIME'), ('Sunday', 'DATE'), ('Aaron', 'PERSON')]
# [('Australia', 'GPE'), ('a few days', 'DATE'), ('John', 'PERSON')]
# [('last night', 'TIME')]
# [('John', 'PERSON'), ('our evening', 'TIME'), ('100%', 'PERCENT')]
# [('Saturday night', 'TIME'), ('John', 'PERSON'), ('Nolita', 'PERSON')]
# [('Tambourine', 'ORG'), ('Trumpet', 'NORP')]
# [('3', 'CARDINAL'), ('27', 'CARDINAL')]
# [('NAME', 'PERSON')]
# [('Dublin', 'GPE'), ('Edinburgh', 'GPE'), ('evening', 'TIME')]
# []
# []
# [('zero', 'CARDINAL'), ('Benedict', 'PERSON')]
# []
# [('Dublin', 'GPE'), ('European', 'NORP'), ('Dublin', 'GPE')]
# [('2', 'CARDINAL')]
# [('The Egg Benedict', 'FAC'), ('Sophie', 'ORG'), ('Sophia', 'PRODUCT')]
# [('last night', 'TIME'), ('monkfish', 'NORP')]
# [('one', 'CARDINAL'), ('Dublin', 'GPE'), ('yesterday', 'DATE'), ('Worcestershire', 'PERSON'), ('Garlic', 'NORP')]
# [('monkfish', 'NORP'), ('Shepard', 'ORG')]
# [('Jonathan Swift', 'PERSON'), ('Alisha', 'PERSON'), ('the night', 'TIME')]
# [('Saturday', 'DATE'), ('evening', 'TIME'), ('Sunday', 'DATE'), ('evening', 'TIME'), ('Ben', 'PERSON'), ('Gucci', 'PERSON'), ('Bow', 'PERSON'), ('the next day', 'DATE'), ('Diago', 'PERSON'), ('Lucas', 'GPE'), ('Argentina', 'GPE'), ('Fortis', 'GPE'), ('Fortis', 'PERSON'), ('Greek', 'NORP')]
# [('first', 'ORDINAL')]
# [('a week', 'DATE'), ('2', 'CARDINAL'), ('holidays season', 'DATE'), ("Valentine's Day", 'DATE')]
# [('20 minutes', 'TIME'), ('25 euro', 'QUANTITY')]
# []
# [('100', 'CARDINAL')]
# [('Friday', 'DATE'), ('night', 'TIME'), ('Dublin', 'GPE'), ('one', 'CARDINAL'), ('25 minutes', 'TIME')]
# [('Dessert', 'PERSON'), ('a few hours', 'TIME')]
# []
# [('evening', 'TIME')]
# []
# [('Ireland', 'GPE'), ('Love', 'WORK_OF_ART'), ('3 hours', 'TIME'), ('Manhattan', 'GPE'), ('12', 'CARDINAL'), ('Irish', 'NORP')]
# []
# [('afternoon', 'TIME'), ('💖', 'PERSON')]
# []
# []
# [('Drinks', 'PERSON')]
# [('Elliot', 'PERSON'), ('5pm', 'TIME')]
# [('Dublin', 'GPE'), ('Dublin', 'GPE'), ('Café Reichard', 'PERSON'), ('Cologne', 'GPE')]
# [('One', 'CARDINAL'), ('Dublin', 'GPE')]
# [('greenery', 'ORG'), ('second', 'ORDINAL'), ('🤣', 'NORP')]
# [('Booking', 'ORG')]
# [('early morning', 'TIME')]
# [('winter', 'DATE')]
# []
# [('9th', 'ORDINAL'), ('December', 'DATE')]
# []
# []
# [('5.95', 'MONEY'), ('10', 'CARDINAL')]
# [('two', 'CARDINAL')]
# [('evening', 'TIME'), ('Irish', 'NORP')]
# [('Dublin', 'GPE'), ('years', 'DATE')]
# []
# []
# [('12,5%', 'PERCENT')]
# []
# [('Seabeam', 'NORP'), ('one', 'CARDINAL'), ('one', 'CARDINAL')]
# [('thousand', 'CARDINAL')]
# [('♿', 'LAW')]
# []
# []
# [('first', 'ORDINAL'), ('Two', 'CARDINAL'), ('Sunday', 'DATE'), ('night', 'TIME'), ('three', 'CARDINAL'), ('four', 'CARDINAL'), ('The night', 'TIME')]
# [('one', 'CARDINAL'), ('10', 'CARDINAL')]
# []
# [('Sunday', 'DATE')]
# []
# [('the Rustic Stone', 'ORG'), ('Firstly', 'ORDINAL'), ('Secondly', 'ORDINAL'), ('Thirdly', 'ORDINAL'), ('half', 'CARDINAL')]
# []
# [('one', 'CARDINAL'), ('at least 3 days', 'DATE'), ('Palau', 'GPE'), ('3', 'CARDINAL')]
# []
# [('9pm', 'TIME'), ('Dublin', 'GPE'), ('the Fade Street Restaurant', 'ORG')]
# [('3', 'CARDINAL')]
# []
# []
# []
# [('50th', 'ORDINAL'), ('Fade Street Social', 'FAC'), ('the minute', 'TIME'), ('second', 'ORDINAL'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('Fade Street Social', 'ORG')]
# [('Last Saturday', 'DATE'), ('Ugo', 'ORG')]
# [('over 40 minutes', 'TIME'), ('the night', 'TIME')]
# [('First', 'ORDINAL'), ('Dylan', 'PERSON')]
# [('hour', 'TIME')]
# [('Truffle', 'ORG')]
# [('3', 'CARDINAL'), ('EXTREMELY', 'ORG')]
# [('5', 'CARDINAL'), ('Alex', 'PERSON'), ('Alexandra', 'PERSON'), ('evening', 'TIME'), ('4', 'CARDINAL'), ('Woodfire', 'GPE')]
# []
# [('One', 'CARDINAL'), ('two', 'CARDINAL')]
# [('Dublin', 'GPE')]
# [('one', 'CARDINAL'), ('Dublin', 'GPE'), ('Dublin', 'GPE')]
# [('Burger', 'ORG'), ('Crust', 'ORG'), ('about 3x', 'CARDINAL'), ('Monday', 'DATE')]
# []
# [('first', 'ORDINAL')]
# [('Google', 'ORG')]
# [('3', 'CARDINAL'), ('Dublin', 'GPE'), ('Dylan McGrath', 'PERSON'), ('Solid 5/5', 'PRODUCT'), ('the past 7+ years', 'DATE')]
# [('Ireland', 'GPE')]
# [('Paddy', 'GPE'), ('one', 'CARDINAL')]
# []
# []
# [('Dubliner', 'ORG')]
# [('Mac', 'PERSON'), ('Mac', 'PERSON'), ('Cod', 'PERSON')]
# []
# []
# [('Tonight', 'TIME'), ('two', 'CARDINAL'), ('Sauvignon', 'GPE'), ('19.90', 'MONEY'), ('two', 'CARDINAL')]
# [('3', 'CARDINAL')]
# [('40', 'CARDINAL'), ('4', 'CARDINAL'), ('400 euro', 'QUANTITY'), ('Meh', 'PERSON')]
# [('Frist', 'PERSON'), ('55', 'CARDINAL'), ('Jay', 'PERSON'), ('night', 'TIME'), ('Chris', 'PERSON')]
# []
# [('Saturday', 'DATE'), ('two', 'CARDINAL'), ('ribeye', 'GPE'), ('five', 'CARDINAL'), ('only one', 'CARDINAL'), ('about one', 'CARDINAL')]
# []
# []
# [('spanish', 'NORP'), ('second', 'ORDINAL')]
# [("George's Street Arcade", 'ORG'), ('a pay day', 'DATE'), ('Thursday', 'DATE'), ('26', 'MONEY'), ('two', 'CARDINAL'), ('bread & dip', 'ORG')]
# [('dublin', 'GPE')]
# [('breads & dips', 'ORG'), ('INCREDIBLE', 'ORG')]
# [('2', 'CARDINAL'), ('17', 'MONEY'), ('patatas bravas', 'ORG'), ('25', 'MONEY'), ('8,50', 'MONEY'), ('a couple of weeks', 'DATE'), ('next week', 'DATE')]
# [('One', 'CARDINAL')]
# [('Saturday', 'DATE')]
# []
# [('today', 'DATE'), ('4', 'CARDINAL'), ('3 Guinness', 'QUANTITY'), ('one', 'CARDINAL'), ('at least 10 minutes', 'TIME'), ('30 minutes', 'TIME'), ('4', 'CARDINAL'), ('16', 'CARDINAL'), ('max', 'PERSON')]
# []
# [('5', 'CARDINAL')]
# []
# [('14€', 'DATE'), ('IMO', 'ORG'), ('17€', 'CARDINAL')]
# [('One', 'CARDINAL'), ('three', 'CARDINAL'), ('Cuisine', 'PERSON'), ('5', 'CARDINAL')]
# [('25 minutes', 'TIME'), ('Sangria', 'GPE'), ('20 minutes', 'TIME'), ('12.5%', 'PERCENT')]
# [('nights', 'TIME'), ('Creme de Menthe', 'PERSON')]
# [("St Patty's", 'PERSON'), ('University of Dublin', 'ORG')]
# [('Saturday day', 'DATE'), ('only one', 'CARDINAL')]
# []
# [('Guinness', 'ORG')]
# []
# []
# [('Spanish', 'NORP'), ('Dublin', 'GPE'), ('1', 'CARDINAL'), ('1', 'CARDINAL')]
# [('the Market Bar', 'ORG'), ('Aubergine', 'PERSON')]
# [('first', 'ORDINAL'), ('Irish', 'NORP')]
# [('seventeen', 'CARDINAL'), ('a hen weekend', 'DATE'), ('Dublin', 'GPE')]
# [('100', 'MONEY'), ('two', 'CARDINAL'), ('3', 'CARDINAL')]
# [('last night', 'TIME'), ('first', 'ORDINAL'), ('The Market Bar', 'ORG'), ('12.5%', 'PERCENT'), ('two', 'CARDINAL')]
# [('5', 'CARDINAL'), ('15', 'CARDINAL'), ('20', 'CARDINAL'), ('between 15', 'CARDINAL'), ('1', 'CARDINAL')]
# [('Ireland', 'GPE'), ('Temple Bar 🤟🤤', 'ORG'), ('one', 'CARDINAL'), ('Beans', 'NORP'), ('Ireland', 'GPE'), ('Dublin', 'GPE')]
# [('a couple of weeks ago', 'DATE'), ('1yr', 'ORDINAL'), ('first', 'ORDINAL')]
# []
# [('2', 'CARDINAL'), ('2', 'CARDINAL'), ('koftas', 'ORG'), ('Lunch', 'PRODUCT'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('17euros', 'CARDINAL')]
# []
# [('last Friday', 'DATE'), ('The Market Bar', 'WORK_OF_ART'), ('Giselle', 'ORG')]
# [('Tapas', 'ORG'), ('10/10', 'CARDINAL')]
# [('Only 1', 'CARDINAL')]
# [('€13 euro', 'MONEY'), ('five', 'CARDINAL'), ('12.5%', 'PERCENT')]
# []
# [('2', 'CARDINAL')]
# [('American', 'NORP'), ('evening', 'TIME')]
# [('Tapas', 'ORG'), ('Mojito', 'ORG'), ('Covid', 'PERSON')]
# [('4:15', 'TIME'), ('4pm', 'TIME'), ('Covid', 'GPE'), ('36', 'MONEY'), ('six', 'CARDINAL'), ('three', 'CARDINAL'), ('23', 'MONEY'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('four', 'CARDINAL'), ('1 hour 45', 'TIME')]
# [('all night', 'TIME'), ('the next day', 'DATE'), ('a few hours later', 'TIME'), ('one', 'CARDINAL')]
# [('two', 'CARDINAL'), ('12.5%', 'PERCENT'), ('Guinness', 'ORG'), ('7€.', 'CARDINAL')]
# [('4', 'CARDINAL'), ('First', 'ORDINAL'), ('Sunday', 'DATE'), ('night', 'TIME')]
# [('the Market Bar', 'ORG'), ('the Group Menu', 'ORG'), ('the day', 'DATE'), ('12', 'CARDINAL'), ('one', 'CARDINAL'), ('12', 'CARDINAL')]
# [('Sunday', 'DATE'), ('Brad', 'PERSON'), ('potato newbas', 'PERSON'), ('5', 'CARDINAL')]
# [('Sunday', 'DATE'), ('Sunday', 'DATE'), ('Yorkshire', 'PERSON')]
# []
# [('Cozy', 'PERSON'), ('half', 'CARDINAL')]
# [('Euro', 'WORK_OF_ART'), ('years ago', 'DATE'), ('one', 'CARDINAL'), ('Dublin', 'GPE')]
# [('3', 'CARDINAL'), ('2', 'CARDINAL'), ('100', 'MONEY')]
# [('only 2', 'CARDINAL')]
# [('Brasserie Sixty6', 'PERSON')]
# [('Smokey', 'GPE')]
# [('Thursday', 'DATE'), ('evening', 'TIME')]
# [('First', 'ORDINAL'), ('years', 'DATE'), ('one hour', 'TIME'), ('0', 'CARDINAL'), ('10', 'CARDINAL')]
# [('Irish', 'NORP')]
# [('first', 'ORDINAL'), ('Brasserie Sixty6', 'PERSON'), ('last Friday', 'DATE'), ('afternoon', 'TIME'), ('Aaron', 'PERSON'), ('Daniel', 'PERSON'), ('Donna', 'PERSON')]
# [('13 euro', 'QUANTITY'), ('Ireland', 'GPE'), ('34 euro', 'QUANTITY')]
# [('Dublin', 'GPE'), ('Sixty6', 'PERSON'), ('a bad day', 'DATE')]
# []
# [('Three', 'CARDINAL'), ('last night', 'TIME'), ('2', 'CARDINAL'), ('2', 'CARDINAL'), ('between 3', 'CARDINAL'), ('2', 'CARDINAL'), ('2', 'CARDINAL'), ('12.5%', 'PERCENT'), ('3', 'CARDINAL')]
# [('Shepard', 'ORG'), ('Ireland', 'GPE')]
# [('6', 'CARDINAL'), ('8pm', 'TIME'), ('9pm', 'TIME'), ('Saturday', 'DATE'), ('night', 'TIME'), ('8pm', 'TIME'), ('Dublin City Centre', 'FAC')]
# []
# []
# []
# []
# [('four', 'CARDINAL'), ('half', 'CARDINAL'), ('week', 'DATE')]
# [('one', 'CARDINAL')]
# []
# [('12.5%', 'PERCENT'), ('Service Charge', 'ORG'), ('only 2', 'CARDINAL')]
# [('Dublin City Centre', 'FAC')]
# [('the morning', 'TIME')]
# []
# []
# [('Cassio', 'PERSON')]
# [('15 minutes', 'TIME'), ('one hour', 'TIME')]
# []
# [('Malbec', 'ORG')]
# []
# [('tonight', 'TIME')]
# []
# [('Tomahawk', 'PRODUCT'), ('Argentina', 'GPE'), ('Saturday', 'DATE'), ('night', 'TIME'), ('jack', 'PERSON'), ('Friday/Saturday', 'DATE')]
# [('15', 'CARDINAL')]
# []
# [('two', 'CARDINAL'), ('1', 'CARDINAL'), ('1', 'CARDINAL'), ('six', 'CARDINAL'), ('Dylan', 'PERSON')]
# []
# [('Food', 'ORG'), ('second', 'ORDINAL')]
# [('32.50', 'CARDINAL'), ('Berlin', 'GPE'), ('18', 'CARDINAL'), ('Rip', 'PERSON'), ('Ireland', 'GPE')]
# [('Veggie', 'PERSON')]
# [('34', 'MONEY'), ('12.5%', 'PERCENT'), ('73', 'MONEY')]
# [('evening', 'TIME'), ('39€', 'CARDINAL'), ('one', 'CARDINAL')]
# [('3', 'CARDINAL')]
# [('13', 'CARDINAL'), ('28.01.2023@5pm', 'CARDINAL')]
# [('the day', 'DATE')]
# [('the evening', 'TIME'), ('7pm', 'TIME'), ('9pm', 'TIME'), ('Hubby', 'PERSON')]
# [('6', 'CARDINAL'), ('two consecutive days', 'DATE'), ('Dublin', 'GPE')]
# [('William', 'PERSON'), ('second', 'ORDINAL'), ('Italy', 'GPE'), ('a few night', 'TIME'), ('Dublin', 'GPE'), ('mango &', 'ORG'), ('The Church', 'ORG'), ('Dublin', 'GPE'), ('Church', 'ORG')]
# [('Dublin', 'GPE'), ('the Church Cafe', 'ORG'), ('two', 'CARDINAL'), ('15', 'CARDINAL')]
# [('Church', 'ORG'), ('Irish', 'NORP')]
# [('Church', 'ORG'), ('Dublin', 'GPE'), ('Irish', 'NORP'), ('Sundays', 'DATE')]
# [('25%', 'PERCENT')]
# [('One', 'CARDINAL'), ('Irish', 'NORP'), ('Sunday to Thursday', 'DATE'), ('Dublin', 'GPE')]
# [('Dublin', 'GPE')]
# []
# [('Guinness', 'ORG')]
# [('Irish', 'NORP'), ('a night', 'TIME'), ('Guinness', 'ORG'), ('date night', 'TIME')]
# []
# [('Highlights', 'GPE'), ('Dublin', 'GPE')]
# [('Dublin', 'GPE'), ('Arthur  Guinness', 'ORG')]
# [('Dublin', 'GPE'), ('3', 'CARDINAL')]
# [('midweek', 'DATE'), ('evening', 'TIME'), ('May', 'DATE')]
# [('Dublin', 'GPE')]
# []
# [('IAN', 'ORG'), ('Ian', 'PERSON')]
# [('Irish', 'NORP'), ('one', 'CARDINAL'), ('Georg Friedrich Handel', 'PERSON'), ('Guinness', 'ORG'), ('Guinness', 'ORG')]
# [('5', 'CARDINAL'), ('Ireland', 'GPE'), ('Dublin', 'GPE')]
# [('the weekend', 'DATE')]
# [('Great Ambiance', 'ORG'), ('5', 'CARDINAL'), ('Irish', 'NORP')]
# []
# [('Church', 'ORG'), ('Dublin', 'GPE')]
# [('today', 'DATE')]
# [('Leon', 'PERSON')]
# [('one', 'CARDINAL'), ('Dublin', 'GPE'), ('Chardonnay', 'ORG'), ('Apperol', 'ORG'), ('55', 'MONEY'), ('Apperol', 'PERSON'), ('about 5 minutes', 'TIME')]
# [('Dublin', 'GPE')]
# []
# [('Irish', 'NORP')]
# [('2nd', 'ORDINAL'), ('first', 'ORDINAL'), ('Amsterdam', 'GPE')]
# [('Irish', 'NORP'), ('half an hour', 'TIME')]
# [('today', 'DATE'), ('a hot day', 'DATE')]
# [('Truly Amazing Place', 'ORG'), ('Church', 'ORG')]
# [('irish', 'NORP')]
# [('40-minute', 'TIME'), ('Chips', 'ORG'), ('Grilled Cornfed Irish Chicken Supreme', 'ORG'), ("the Chef's Special", 'ORG'), ('Teriyaki Marinated Sea Bass', 'ORG'), ('Dessert', 'PERSON')]
# []
# []
# [('Lamb', 'PERSON'), ('5:30', 'TIME'), ('Tuesday', 'DATE')]
# []
# [('one', 'CARDINAL')]
# [('our last night', 'TIME'), ('Ireland', 'GPE'), ('Irish', 'NORP'), ('Katie', 'PERSON'), ('One', 'CARDINAL'), ('the next day', 'DATE'), ('Dublin', 'GPE')]
# [('Dublin', 'GPE'), ('Dublin', 'GPE')]
# []
# [('one', 'CARDINAL'), ('Dublin', 'GPE')]
# []
# [('Peachy Blinder', 'PERSON'), ('The Chicken Supreme and Traditional Lamb', 'ORG'), ('a day', 'DATE')]
# []
# [('3', 'CARDINAL'), ('60€.', 'CARDINAL'), ('9.15pm', 'CARDINAL')]
# [('Sea Bass', 'PERSON'), ('a few minutes', 'TIME')]
# [('Dublin', 'GPE'), ('earlier this year', 'DATE'), ('One', 'CARDINAL')]
# [('SOLE Seafood & Grill', 'ORG'), ('the evening', 'TIME'), ('two', 'CARDINAL'), ('French', 'NORP'), ('Sauvignon', 'GPE'), ('Chips', 'ORG'), ('evening', 'TIME'), ('SOLE Seafood & Grill', 'ORG')]
# [('Sole', 'PERSON'), ('Wally', 'PERSON'), ('Intuitive &', 'ORG')]
# [('night last night', 'TIME'), ('SOLE food amazing', 'ORG'), ('Prawn', 'PERSON'), ('2', 'CARDINAL'), ('the day', 'DATE')]
# [('Jonata', 'PERSON'), ('South African', 'NORP')]
# [('about 2 hours', 'TIME')]
# []
# [('dublin city', 'GPE')]
# []
# [('Saturday', 'DATE'), ('Sole', 'ORG'), ('Sea Bass', 'PERSON'), ('Thai', 'NORP'), ('Martin', 'PERSON'), ('Bass', 'PERSON')]
# [('the SOLE Seafood Tower', 'ORG')]
# [('Sunday', 'DATE'), ('evening', 'TIME'), ('18:30', 'TIME'), ('this evening', 'TIME')]
# [('6', 'CARDINAL')]
# [('Sole', 'ORG'), ('Bruno', 'PERSON'), ('Gustavo', 'ORG')]
# []
# [('Sunday', 'DATE')]
# [('a year ago', 'DATE'), ('Martin', 'PERSON'), ('two', 'CARDINAL'), ('6', 'CARDINAL'), ('Achill', 'PERSON'), ('Connemara', 'PERSON'), ('Lobster Thermador', 'PERSON'), ('first', 'ORDINAL'), ('85e', 'DATE'), ('every penny', 'MONEY'), ('Monkfish', 'NORP'), ('meaty', 'PERSON'), ('arancini', 'PERSON'), ('Glass', 'PERSON'), ('NZ Sauvignon', 'ORG'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT'), ('Glass', 'PERSON'), ('5', 'CARDINAL'), ('230e', 'PRODUCT'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT'), ('☆', 'PRODUCT')]
# [('Google', 'ORG')]
# [('Steak', 'PERSON')]
# [('Fire', 'GPE'), ('Fire', 'GPE')]
# []
# [('hours', 'TIME'), ('6/10', 'CARDINAL'), ('10/10', 'CARDINAL'), ('8/10', 'CARDINAL'), ('Oyster', 'FAC')]
# [('Second', 'ORDINAL'), ('first', 'ORDINAL'), ('Bruno', 'PERSON'), ('3', 'CARDINAL'), ('€60', 'LAW'), ('Sole', 'ORG'), ('one', 'CARDINAL')]
# [('Alessandra', 'NORP')]
# []
# [('our first night', 'TIME'), ('Dublin', 'GPE'), ('Lucas', 'GPE'), ('10/10', 'CARDINAL')]
# [('One', 'CARDINAL')]
# [('today', 'DATE'), ('Sole', 'NORP'), ('Kasia', 'PERSON')]
# []
# [('over 100', 'CARDINAL'), ('at least two', 'CARDINAL'), ('one', 'CARDINAL'), ('650', 'MONEY')]
# []
# [('Three', 'CARDINAL'), ('five', 'CARDINAL'), ('About 20 minutes', 'TIME'), ('two', 'CARDINAL'), ('about ten minutes', 'TIME'), ('Joe', 'PERSON'), ('Two', 'CARDINAL'), ('three', 'CARDINAL'), ('Joe', 'PERSON'), ('Joe', 'PERSON'), ('Ireland', 'GPE'), ('1:1', 'CARDINAL'), ('first', 'ORDINAL'), ('Ireland', 'GPE'), ('Ireland', 'GPE'), ('US', 'GPE'), ('Ireland', 'GPE'), ('US', 'GPE'), ('Joe', 'PERSON')]
# [('Sole', 'PERSON'), ('First', 'ORDINAL')]
# [('Jesus', 'PERSON')]
# [('Niamh', 'PERSON'), ('Lucas', 'GPE')]
# []
# [('Very Highly Recommended', 'ORG')]
# [('Love', 'WORK_OF_ART'), ('Husband', 'PERSON'), ('four', 'CARDINAL'), ('240', 'MONEY'), ('Dublin', 'GPE'), ('SOLE', 'ORG')]
# [('Jesus', 'PERSON'), ('Gustavo', 'PERSON')]
# [('5', 'CARDINAL'), ('Dublin', 'GPE'), ('Sole', 'PERSON'), ('number 1', 'CARDINAL'), ('5', 'CARDINAL')]
# [('Sole', 'PERSON'), ('eight', 'CARDINAL'), ('Cloudy Bay', 'LOC'), ('Bogdan', 'PERSON'), ('Bogdan', 'PERSON')]
# [('the day', 'DATE')]
# [('Ireland', 'GPE'), ('🙂', 'GPE')]
# [('6', 'CARDINAL'), ('100%', 'PERCENT')]
# [('SOLE', 'ORG')]
# [('tonight', 'TIME'), ('Liverpool', 'GPE'), ('Dublin', 'GPE')]
# [('Incredible food & service', 'ORG')]
# [('Thiago', 'GPE'), ('Thai', 'NORP'), ('Thai', 'NORP'), ('SOLE food and', 'ORG')]
# [('Irish', 'NORP'), ('Irish', 'NORP'), ('second', 'ORDINAL'), ('Dublin', 'GPE')]
# [('One', 'CARDINAL'), ('Dublin', 'GPE'), ('Irish', 'NORP'), ('Guinness', 'ORG'), ('bread & butter', 'ORG'), ('Coffe', 'ORG'), ('Bailey', 'PERSON'), ('Dublin', 'GPE')]
# [('Irish', 'NORP')]
# [('Dublin', 'GPE'), ('2', 'CARDINAL')]
# [('Cozy', 'PERSON'), ('Dublin', 'GPE')]
# []
# [('Ireland', 'GPE'), ('Scotland', 'GPE')]
# []
# [('first', 'ORDINAL'), ('Dublin', 'GPE'), ('the weekend', 'DATE'), ('American', 'NORP')]
# []
# [('Irish', 'NORP'), ('Bacon', 'ORG'), ('first', 'ORDINAL'), ('70', 'DATE')]
# [('Dublin', 'GPE'), ('our first night', 'TIME'), ('irish', 'NORP'), ('the morning', 'TIME'), ('a night', 'TIME'), ('irish', 'NORP'), ('the day before a day', 'DATE'), ('irish', 'NORP'), ('Dublin', 'GPE')]
# [('Food & PRESENTATION', 'ORG'), ('5', 'DATE'), ('Claudia', 'PERSON')]
# [('Dublin', 'GPE'), ('first', 'ORDINAL')]
# [('Temple Bar', 'LOC'), ('Dublin', 'GPE'), ('Irish', 'NORP')]
# [('the first day', 'DATE'), ('Ireland', 'GPE'), ('Irish', 'NORP'), ('only one', 'CARDINAL')]
# [('Irish', 'NORP'), ('a week', 'DATE'), ('Dublin', 'GPE'), ('Galway', 'GPE'), ('Ireland', 'GPE'), ('two', 'CARDINAL'), ('the Old Mill', 'FAC'), ('the Emerald Isle', 'LOC')]
# [('One', 'CARDINAL'), ('20€.', 'CARDINAL')]
# [('Dublin', 'GPE'), ('Dublin', 'GPE'), ('irish', 'NORP')]
# [('Christmas', 'DATE'), ('Gerry', 'PERSON')]
# [('Covid', 'PERSON')]
# [('Irish', 'NORP'), ('2', 'CARDINAL'), ('2', 'CARDINAL'), ('1', 'CARDINAL'), ('60', 'MONEY')]
# [('Irish', 'NORP'), ('Irish', 'NORP'), ('Guinness', 'ORG'), ('about half', 'CARDINAL')]
# []
# []
# [('the day', 'DATE'), ('Dublin', 'GPE'), ('America', 'GPE'), ('Dublin', 'GPE'), ('First', 'ORDINAL'), ('two', 'CARDINAL'), ('The Old Mill', 'PERSON'), ('Fleet Street', 'FAC'), ('the days', 'DATE'), ('one', 'CARDINAL'), ('The Old Mill', 'ORG'), ('about half-full', 'CARDINAL'), ('two', 'CARDINAL'), ('first', 'ORDINAL'), ('Juicy', 'PERSON'), ('a few minutes', 'TIME'), ('The Old Mill', 'ORG'), ('our evening', 'TIME')]
# [('dublin', 'GPE')]
# [('Guinness', 'ORG'), ('Irish', 'NORP')]
# [('Irish', 'NORP')]
# [('Temple Bar', 'LOC')]
# []
# [('Dublin', 'GPE')]
# [('Irish', 'NORP'), ('8 years old', 'DATE')]
# []
# []
# [('2', 'CARDINAL')]
# [('one', 'CARDINAL'), ('10-15%', 'PERCENT'), ('one', 'CARDINAL')]
# [('Ireland', 'GPE')]
# [('Irish', 'NORP')]
# []
# [('Irish', 'NORP'), ('the day', 'DATE')]
# [('Irish', 'NORP')]
# [('about 80%', 'PERCENT')]
# [('Irish', 'NORP'), ('Dublin', 'GPE')]
# [('more than 40 minutes', 'TIME'), ('us', 'GPE')]
# []
# []
# [('Dublin', 'GPE'), ('2', 'CARDINAL'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('Ideal', 'ORG')]
# [('irish', 'NORP'), ('Mexican', 'NORP')]
# [('Irish Pub', 'ORG'), ('1', 'MONEY'), ('Guinness', 'ORG'), ('Moscow', 'GPE'), ('Mules', 'PERSON'), ('a week', 'DATE'), ('Dublin', 'GPE'), ('Irish Pub', 'ORG')]
# [('Spanish', 'NORP'), ('Spanish', 'NORP'), ('camden street', 'FAC')]
# [('around 9pm', 'TIME'), ('Sunday', 'DATE'), ('Spanish', 'NORP')]
# [('Madrid', 'GPE'), ('Spain', 'GPE'), ('Javi', 'PERSON')]
# [('evening', 'TIME'), ('Spain', 'GPE'), ('Dublin', 'GPE')]
# [('Spain', 'GPE'), ('Spain', 'GPE'), ('Spanish', 'NORP'), ('Irish', 'NORP'), ('Dublin', 'GPE')]
# [('Dublin', 'GPE'), ('Manchego', 'ORG'), ('Tomaquet', 'WORK_OF_ART'), ('Ham Croquettes', 'PERSON'), ('Bomba de Barcelona', 'GPE')]
# [('spanish', 'NORP')]
# [('Dublin', 'GPE'), ('Spain', 'GPE'), ('pan con tomate', 'PERSON')]
# [('Dublin', 'GPE'), ('“las tapas de Lola', 'FAC'), ('1', 'CARDINAL'), ('2', 'CARDINAL'), ('Spain', 'GPE'), ('3', 'CARDINAL'), ('4', 'CARDINAL'), ('croquetas', 'ORG'), ('gambas', 'ORG'), ('WOW', 'ORG'), ('more than 4 years', 'DATE')]
# [('Dublin', 'GPE'), ('Ireland', 'GPE')]
# [('Dublin', 'GPE'), ('Ireland', 'GPE'), ('Spain', 'GPE')]
# [('four', 'CARDINAL')]
# [('Spanish', 'NORP')]
# []
# []
# [('Spanish', 'NORP')]
# [('first', 'ORDINAL'), ('this weekend', 'DATE'), ('Superb', 'NORP'), ('Carrillada', 'ORG')]
# [('6 dishes', 'QUANTITY'), ('only 2', 'CARDINAL')]
# [('Burnt', 'GPE')]
# [('last week', 'DATE'), ('6', 'CARDINAL'), ('between 2 of us', 'DATE'), ('5', 'CARDINAL'), ('about 15', 'CARDINAL'), ('6', 'CARDINAL'), ('37.50', 'MONEY'), ('second', 'ORDINAL')]
# [('One', 'CARDINAL'), ('10/10', 'CARDINAL'), ('Roman', 'PERSON')]
# [('more than five', 'CARDINAL'), ('Dublin', 'GPE'), ('two', 'CARDINAL'), ('I.', 'ORG')]
# [('Dublin', 'GPE'), ('Ireland', 'GPE')]
# []
# [('about 5', 'CARDINAL'), ('2', 'CARDINAL')]
# [('Dubliner', 'ORG'), ('Las Tapas De Lola', 'FAC'), ('Ireland', 'GPE'), ('Dublin', 'GPE')]
# []
# [('Anna', 'PERSON'), ('Vanessa', 'PERSON'), ('5', 'CARDINAL'), ('Love', 'WORK_OF_ART')]
# [('Spanish', 'NORP')]
# [('Wexford St.', 'PERSON')]
# [('patatas bravas', 'ORG'), ('Spain', 'GPE')]
# [('snarky', 'ORG')]
# [('Dublin', 'GPE'), ('Tapas de Lola', 'PERSON'), ('10 years', 'DATE')]
# [('Spanish', 'NORP'), ('Spain', 'GPE'), ('the night', 'TIME')]
# [('3', 'CARDINAL')]
# []
# []
# [('Dublin', 'GPE'), ('Spanish', 'NORP'), ('every cent', 'MONEY')]
# [('Efficient', 'PERSON')]
# [('Sunday', 'DATE')]
# [('Tuesday', 'DATE'), ('evening', 'TIME'), ('at least 30', 'CARDINAL')]
# [('one', 'CARDINAL'), ('Spain', 'GPE'), ('one', 'CARDINAL'), ('5', 'CARDINAL'), ('that night', 'TIME')]
# [('second', 'ORDINAL'), ('first', 'ORDINAL')]
# [('Spain', 'GPE'), ('25 years', 'DATE'), ('Spanish', 'NORP'), ('Dublin', 'GPE'), ('Spanish', 'NORP'), ('Spanish', 'NORP'), ('the Patatas Bravas', 'ORG'), ('Spanish', 'NORP'), ('Fideuá', 'PRODUCT'), ('Dublin', 'GPE'), ('Barcelona', 'GPE'), ('two', 'CARDINAL'), ('Pimientos del Padrón', 'PERSON'), ('Crema Catalana', 'PERSON')]
# [('croquetas', 'ORG'), ('Nice', 'GPE'), ('Andrea', 'PERSON')]
# [('12', 'CARDINAL'), ('between 4 of us', 'DATE')]
# [('a week', 'DATE'), ('Dublin', 'GPE')]
# [('Spanish', 'NORP'), ('6', 'CARDINAL')]
# [('Yesterday', 'DATE'), ('first', 'ORDINAL'), ('Las Tapas de Lola', 'FAC'), ('two', 'CARDINAL'), ('Lustau', 'GPE'), ('Mar', 'PERSON'), ('spanish', 'NORP')]
# [('Pulpo a Galicia', 'WORK_OF_ART'), ('Gamba al Ajillo', 'PERSON'), ('the Tarta de Queso', 'ORG'), ('Spanish', 'NORP'), ('Dublin', 'GPE')]
# [('half', 'CARDINAL'), ('BBQ', 'ORG'), ('FANTASTIC', 'ORG')]
# [('dublin', 'GPE')]
# [('Irish', 'NORP'), ('Gresham', 'PERSON')]
# []
# [('Dublin', 'GPE'), ('first', 'ORDINAL')]
# [('20 minutes', 'TIME'), ('Dublin', 'GPE'), ('Dublin', 'GPE')]
# [('nearly 40 years', 'DATE'), ('Flanagans', 'NORP'), ('5', 'CARDINAL')]
# []
# [('one evening', 'TIME'), ('Dublin', 'GPE'), ('this night', 'TIME')]
# [('minutes', 'TIME')]
# []
# [('Italian', 'NORP'), ('Dublin', 'GPE')]
# [('Dublin', 'GPE')]
# [('evening', 'TIME'), ('Menu', 'ORG')]
# []
# [('Dublin', 'GPE'), ('the night', 'TIME')]
# [('that day', 'DATE')]
# [('100%', 'PERCENT')]
# []
# []
# [('the day', 'DATE')]
# [('two', 'CARDINAL'), ('night', 'TIME'), ('Irish', 'NORP'), ('1st night', 'TIME'), ('4.5', 'CARDINAL'), ('Stew', 'PERSON'), ('2nd night', 'TIME'), ('2.5', 'CARDINAL'), ('8', 'CARDINAL')]
# [('Crispy', 'PERSON'), ('Dessert', 'PERSON')]
# [('2', 'CARDINAL'), ('20 minutes', 'TIME')]
# [('two night', 'TIME'), ('dublin', 'GPE')]
# [('Dublin', 'GPE'), ('Beautifully', 'PERSON'), ('all night', 'TIME')]
# [('yesterday', 'DATE'), ('hours', 'TIME')]
# [('yesterday', 'DATE'), ('morning', 'TIME'), ('First', 'ORDINAL')]
# [('First', 'ORDINAL'), ('Dublin', 'GPE'), ('Flanagan', 'ORG'), ('Irish', 'NORP'), ('7', 'CARDINAL')]
# [('Europe', 'LOC'), ('Belfast', 'GPE'), ('a long day', 'DATE')]
# [('the Bap Bun', 'ORG'), ('Dublin', 'GPE')]
# [('irish', 'NORP'), ('5', 'CARDINAL')]
# [('one', 'CARDINAL')]
# [('Seafood', 'ORG'), ('almost 20€', 'CARDINAL')]
# [('two', 'CARDINAL'), ('up to three', 'CARDINAL')]
# [('30 Euro', 'CARDINAL'), ('30', 'CARDINAL')]
# []
# [('Irish', 'NORP')]
# [('Belinda', 'NORP')]
# [('Awesome', 'ORG')]
# [('first', 'ORDINAL'), ('the 1990s', 'DATE'), ('just over €', 'MONEY'), ('2', 'CARDINAL'), ('a half litre', 'QUANTITY'), ('20', 'CARDINAL')]
# []
# [('Christmas', 'DATE'), ('yesterday', 'DATE'), ('2', 'CARDINAL')]
# []
# []
# [('Irish', 'NORP')]
# [('half', 'CARDINAL'), ('Main Course', 'WORK_OF_ART')]
# [('2 different days', 'DATE')]
# [('Dublin', 'GPE')]
# []
# [('1000/10', 'CARDINAL'), ('Michelin', 'PERSON')]
# [('Tried Sophie’s', 'ORG'), ('first', 'ORDINAL'), ('🍷', 'PERSON'), ('a night', 'TIME')]
# [('Saturday', 'DATE'), ('Sophie', 'ORG'), ('100%', 'PERCENT')]
# [('5th', 'ORDINAL'), ('Dublin', 'GPE')]
# [('Second', 'ORDINAL'), ('Sophie', 'ORG'), ('Love', 'WORK_OF_ART')]
# [('Irish', 'NORP')]
# [('12:00pm', 'ORG')]
# [('Sophie', 'ORG')]
# []
# [('Dean', 'PERSON'), ('5th', 'ORDINAL'), ('5th', 'ORDINAL')]
# [('Dublin', 'GPE'), ('the other day', 'DATE'), ('Dublin', 'GPE')]
# [('the next day', 'DATE'), ('Superb', 'NORP'), ('Dublin', 'GPE')]
# []
# []
# [('View\n⭐️ Food', 'PRODUCT')]
# [('first', 'ORDINAL'), ('Dublin', 'GPE'), ('Sophie', 'ORG'), ('Soho House', 'ORG'), ('Chicago', 'GPE'), ('5th', 'ORDINAL'), ('a clear day', 'DATE'), ('Benedict', 'PERSON'), ('11 AM', 'TIME'), ('weekdays', 'DATE')]
# []
# []
# [('3', 'CARDINAL'), ('One', 'CARDINAL')]
# [('100%', 'PERCENT')]
# [('Sophie', 'ORG'), ('Dublin', 'GPE'), ('Steak', 'PERSON'), ('Greens', 'NORP'), ('Nduja', 'ORG'), ('Orecchiette', 'ORG'), ('Pasta Al dente', 'PERSON'), ('Dublin', 'GPE'), ('5', 'CARDINAL'), ('Stephen', 'GPE')]
# [('Dublin', 'GPE'), ('the day', 'DATE'), ('one', 'CARDINAL'), ('Dublin', 'GPE')]
# [('Union Cafe, Elephant', 'ORG'), ('Castle', 'ORG'), ('less than an hour', 'TIME')]
# [('our last morning', 'TIME'), ('Dublin', 'GPE'), ('10am', 'TIME')]
# [('5 minutes', 'TIME'), ('Dublin', 'GPE'), ('Dublin', 'GPE'), ('Thankyou Igor', 'PERSON')]
# [('burger & fries', 'ORG')]
# [('first', 'ORDINAL'), ('Dublin', 'GPE'), ('Sophie', 'ORG')]
# [('5th', 'ORDINAL'), ('Dublin', 'GPE')]
# []
# [('Dublin', 'GPE')]
# [('26', 'MONEY'), ('9', 'MONEY')]
# [('4', 'CARDINAL')]
# [('Sophie', 'ORG')]
# [('Burger', 'ORG')]
# [('Sophie', 'ORG')]
# []
# []
# []
# []
# [('Dublin', 'GPE')]
# [('10/10', 'CARDINAL')]
# []
# []
# [('Vieuws', 'GPE')]
# [('Brunch', 'NORP')]
# [('10%', 'PERCENT')]
# []
# []
# [('the weekend', 'DATE'), ('Italian', 'NORP')]
# [('a few days', 'DATE'), ('The Dean bar', 'FAC')]
# [('one', 'CARDINAL')]
# [('Dublin', 'GPE'), ('Irish', 'NORP'), ('Tara', 'PERSON'), ('Dublin', 'GPE'), ("Ha'penny", 'PRODUCT'), ('Temple Bar', 'ORG'), ('Cod', 'PERSON'), ('one', 'CARDINAL'), ('Dublin', 'GPE')]
# [('a thousand', 'CARDINAL')]
# [('Ireland', 'GPE'), ('Irish', 'NORP')]
# [('Irish', 'NORP'), ('Gnudi', 'PRODUCT')]
# []
# [('The Winding Stair', 'ORG'), ('Irish', 'NORP'), ('The Irish Black Angus', 'ORG'), ('Cheddar', 'GPE'), ('The Winding Stair', 'ORG'), ('Dublin', 'GPE')]
# [('First', 'ORDINAL'), ('Dublin', 'GPE'), ('Sweet', 'PERSON')]
# []
# [('The Winding Stair', 'ORG')]
# []
# [('3', 'CARDINAL'), ('5 minutes', 'TIME')]
# [('Potted', 'ORG'), ('Dingle Bay', 'PRODUCT'), ('Irish', 'NORP'), ('Dublin Bay', 'PERSON'), ('Grilled Organic Irish', 'PRODUCT')]
# [('Turkey', 'GPE')]
# [('winter', 'DATE'), ('Temple Bar', 'LOC')]
# [('Irish', 'NORP'), ('Irish', 'NORP')]
# []
# [('Irish', 'NORP'), ('Irish', 'NORP')]
# [('Main', 'WORK_OF_ART'), ('Ireland', 'GPE')]
# [('The Winding Stair', 'ORG'), ('5', 'MONEY')]
# [('evening', 'TIME'), ('the King Oyster Mushroom', 'ORG')]
# [('Gem', 'PERSON'), ('2', 'CARDINAL'), ('77 Euro', 'QUANTITY')]
# [('two', 'CARDINAL')]
# []
# [('2 week', 'DATE'), ('Ireland', 'GPE'), ('three', 'CARDINAL'), ('Ha’penny Bridge', 'FAC'), ('the last night', 'TIME'), ('two', 'CARDINAL')]
# [('1 &', 'MONEY'), ('6pm', 'TIME'), ('1\nAfter 7pm', 'TIME'), ('Enjoy', 'GPE')]
# [('Food & drink', 'ORG'), ('Sole', 'NORP'), ('Ha’penny Bridge', 'FAC'), ('Summer', 'DATE')]
# [('second', 'ORDINAL'), ('6 years ago', 'DATE')]
# [('Temple Bar', 'LOC'), ('Dublin', 'GPE')]
# []
# [('FRESH', 'ORG'), ('the Winding Stair', 'FAC'), ('Lamb', 'PERSON'), ('Gelato', 'PERSON')]
# [('Irish', 'NORP'), ('Strawberry', 'PERSON')]
# []
# [('One', 'CARDINAL'), ('Dublin', 'GPE'), ('Liffey', 'EVENT')]
# [('a few good days', 'DATE')]
# []
# [('Irish', 'NORP'), ('Cod', 'PERSON')]
# [('Cozy', 'PERSON')]
# [('Cooked', 'PERSON')]
# [('Dubliners', 'NORP'), ('the west coast', 'LOC'), ('The Winding Stair', 'ORG'), ('Dublin', 'GPE')]
# [('MaconVillage', 'ORG'), ('evening', 'TIME')]
# []
# [('Dublin', 'GPE'), ('second', 'ORDINAL'), ('Bixby', 'PERSON'), ('second', 'ORDINAL'), ('Lamb', 'PERSON')]
# []
# [('One', 'CARDINAL'), ('Dublin', 'GPE')]
# [('Dublin', 'GPE'), ('New Years', 'EVENT'), ('5', 'CARDINAL'), ('new year', 'DATE')]
# [('one', 'CARDINAL'), ('Irish', 'NORP')]
# []
# [('the Irish Seafood Chowder', 'ORG')]
# []
# [('9 days', 'DATE'), ('Ireland', 'GPE'), ('around 16:45', 'TIME'), ('17:00', 'TIME'), ('17:25', 'TIME'), ('Checked Out', 'PERSON'), ('Ireland', 'GPE'), ('Irish', 'NORP')]
# [('FX Buckley', 'ORG'), ('a few weeks', 'DATE')]
# [('F.X. Buckley', 'PERSON'), ('Dublin', 'GPE'), ('Porterhouse', 'ORG'), ('two', 'CARDINAL')]
# [('Dublin', 'GPE'), ('two', 'CARDINAL'), ('FX Buckley', 'ORG')]
# [('Felt', 'PERSON'), ('Dublin', 'GPE'), ('a few days', 'DATE')]
# [('Dublin', 'GPE'), ('a few days later', 'DATE')]
# [('22 Oz', 'PERCENT')]
# [('ribeye', 'GPE')]
# [('Dublin', 'GPE')]
# []
# [('4', 'CARDINAL')]
# [('five', 'CARDINAL')]
# [('Friday', 'DATE'), ('Sunday', 'DATE')]
# [('2', 'CARDINAL'), ('Irish', 'NORP'), ('Waiter', 'PERSON')]
# [('Cesar', 'ORG'), ('yesterday', 'DATE'), ('tonight', 'TIME')]
# [('Dublin', 'GPE'), ('nine', 'CARDINAL')]
# [('FX Buckley', 'ORG'), ('Crow Street', 'FAC'), ('Temple Bar', 'ORG'), ('Dublin', 'GPE'), ('Leek', 'PERSON'), ('Potato', 'ORG'), ('Steaks', 'ORG'), ('Cream Spinach', 'PERSON'), ('Parmesan', 'ORG'), ('Pepper Sauce', 'ORG'), ('Dublin', 'GPE')]
# [('Dublin', 'GPE'), ('Never Gonna Give You Up', 'WORK_OF_ART')]
# []
# []
# [('Second', 'ORDINAL'), ('First', 'ORDINAL'), ('2014', 'DATE'), ('evening', 'TIME'), ('six', 'CARDINAL')]
# []
# []
# [('hours', 'TIME')]
# [('Ireland', 'GPE')]
# [('16', 'CARDINAL'), ('the Buckley’s Ale', 'FAC'), ('around €', 'MONEY'), ('two', 'CARDINAL')]
# [('100%', 'PERCENT'), ('Dublin', 'GPE')]
# [('sunday', 'DATE'), ('Dublin', 'GPE')]
# [('two', 'CARDINAL'), ('between three', 'CARDINAL')]
# [('Smokey', 'ORG'), ('2', 'CARDINAL'), ('Greg', 'LOC'), ('6pm', 'TIME')]
# [('Christmas', 'DATE'), ('Dublin', 'GPE')]
# []
# [('4.5', 'CARDINAL')]
# []
# [('100%', 'PERCENT'), ('Double', 'PRODUCT')]
# []
# [('Oyster', 'FAC'), ('Rare', 'GPE')]
# []
# []
# []
# []
# [('sunday', 'DATE')]
# []
# []
# []
# []
# [('French', 'NORP')]
# [('Pate', 'ORG')]
# [('Ireland', 'GPE'), ('2', 'CARDINAL'), ('Thursday', 'DATE'), ('10min', 'CARDINAL')]
# [('Dublin', 'GPE')]
# [('Chapter One', 'LAW'), ('Chapter One', 'LAW'), ('Mikael', 'PERSON'), ('2', 'CARDINAL'), ('Declan', 'NORP'), ('John', 'PERSON'), ('every minute', 'TIME')]
# [('French', 'NORP'), ('Asian', 'NORP'), ('2', 'CARDINAL'), ('Stellar Amuse-bouche', 'PERSON'), ('Limited', 'ORG')]
# []
# [('6', 'CARDINAL'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('Midleton', 'GPE'), ('Chapter One', 'LAW')]
# []
# [('One', 'CARDINAL'), ('two', 'CARDINAL'), ('michellin star', 'ORG'), ('Dublin', 'GPE')]
# [('Chapter One', 'LAW')]
# []
# [('three years ago', 'DATE'), ('This week', 'DATE'), ('Michelin', 'PERSON'), ('months', 'DATE')]
# []
# [('Chapter One', 'LAW'), ('a couple of hours', 'TIME'), ('Dublin', 'GPE'), ('Irish', 'NORP')]
# []
# [('last month', 'DATE'), ('5', 'CARDINAL')]
# []
# [('3', 'CARDINAL'), ('55', 'MONEY'), ('Michelin', 'PERSON')]
# [('Dessert', 'PERSON')]
# []
# [('two', 'CARDINAL'), ('Irish', 'NORP'), ('less than half', 'CARDINAL'), ('around half', 'CARDINAL'), ('Dublin', 'GPE')]
# [('Chapter One', 'LAW'), ('August', 'DATE'), ('every penny', 'MONEY'), ('3', 'CARDINAL')]
# []
# [('recent weeks', 'DATE')]
# []
# [('evening', 'TIME')]
# [('March of 2016', 'DATE'), ('first', 'ORDINAL'), ('Chapter One', 'LAW'), ('Michelin', 'PERSON'), ('5', 'CARDINAL')]
# [('nearly 20 years', 'DATE'), ('NY', 'GPE'), ('Paris', 'GPE'), ('Tokyo', 'GPE'), ('Dubai', 'GPE'), ('half', 'CARDINAL'), ('3', 'CARDINAL'), ('Michelin', 'ORG'), ('Chapter One', 'LAW'), ('Dublin', 'GPE'), ('Chapter One', 'LAW'), ('March 2023', 'DATE'), ('Just a week', 'DATE'), ('10-day', 'DATE'), ('Paris', 'GPE'), ('Dublin', 'GPE'), ('5', 'CARDINAL')]
# [('65 euro', 'QUANTITY')]
# [('45', 'CARDINAL')]
# [('second', 'ORDINAL'), ('last Saturday', 'DATE'), ('weeks', 'DATE'), ('last year', 'DATE')]
# [('Chapter One', 'LAW')]
# [('three', 'CARDINAL'), ('39', 'MONEY'), ('Irish', 'NORP')]
# []
# [('every cent', 'MONEY')]
# []
# [('Dublin', 'GPE'), ('5 days', 'DATE'), ('one evening', 'TIME'), ('Chapter One', 'LAW'), ('3', 'CARDINAL'), ('Pedro Ximinez', 'PERSON')]
# [('one', 'CARDINAL'), ('Irish Wiskey Coffee', 'ORG'), ('Chapter One', 'LAW'), ('Michelin', 'PERSON')]
# []
# []
# []
# [('Dublin', 'GPE'), ('Pre-Covid', 'PERSON')]
# [('Comte', 'ORG'), ('days', 'DATE'), ('Lobster', 'PERSON'), ('third', 'ORDINAL')]
# []
# [('Superb', 'PERSON')]
# [('One', 'CARDINAL')]
# [('Chapter One', 'LAW'), ('Ross &', 'ORG')]
# []
# [('Dublin', 'GPE')]
# [('several months ago', 'DATE'), ('Jimmy', 'PRODUCT')]
# [('10/10', 'CARDINAL')]
# []
# [('Crème de', 'PERSON'), ('Crème', 'PERSON'), ('Guinness', 'ORG')]
# [('Google', 'ORG'), ('Dublin', 'GPE')]
# [('Irish', 'NORP'), ('15min', 'CARDINAL'), ('60eur', 'CARDINAL')]
# [('three', 'CARDINAL'), ('a nice evening', 'TIME')]
# []
# [('Saturday', 'DATE'), ('2 hours', 'TIME'), ('4', 'CARDINAL'), ('2 hours', 'TIME')]
# []
# [('Dublin', 'GPE'), ('more than one', 'CARDINAL')]
# [('two', 'CARDINAL'), ('2 hours', 'TIME')]
# []
# [('Dublin', 'GPE'), ('Dublin', 'GPE'), ('Cozy', 'PERSON')]
# [('Michelin', 'PERSON'), ('Irish', 'NORP'), ('un', 'ORG'), ('Supermacs', 'PRODUCT'), ('65e', 'DATE'), ('3', 'CARDINAL'), ('40e', 'CARDINAL'), ('Felt', 'PERSON'), ('Six By Nico', 'WORK_OF_ART'), ('6', 'CARDINAL'), ('60e', 'DATE')]
# []
# []
# [('Saturday 5', 'DATE'), ('roughly 20', 'CARDINAL'), ('9', 'CARDINAL'), ('2', 'CARDINAL'), ('2 hours', 'TIME'), ('3', 'CARDINAL'), ('3', 'CARDINAL'), ('3', 'CARDINAL'), ('3', 'CARDINAL'), ('Merlot', 'GPE'), ('fig', 'ORG'), ('tomato starter', 'PERSON'), ('half', 'CARDINAL')]
# [('five', 'CARDINAL'), ('Surf', 'PERSON'), ('Turf', 'PERSON')]
# [('Recommend', 'ORG'), ('Dublin', 'GPE'), ('first', 'ORDINAL')]
# []
# [('5', 'CARDINAL'), ('3', 'CARDINAL'), ('OMMFG', 'ORG')]
# [('Ireland', 'GPE'), ('3 years', 'DATE'), ('SCRUMPTIOUS', 'ORG'), ('less than 5', 'CARDINAL')]
# [('first', 'ORDINAL'), ('a few years ago', 'DATE'), ('65', 'MONEY')]
# [('4', 'CARDINAL'), ('wellington', 'GPE'), ('wellington', 'GPE'), ('Guinness', 'ORG'), ('Dublin', 'GPE'), ('Mulligan', 'PERSON')]
# [('autumn', 'DATE'), ('40', 'MONEY')]
# [('Dublin', 'GPE'), ('one day', 'DATE')]
# []
# [('Wellington', 'GPE'), ('Camembert', 'PERSON'), ('65€', 'QUANTITY')]
# [('65', 'DATE'), ('30', 'CARDINAL'), ('Beef', 'WORK_OF_ART'), ('Brie', 'PERSON'), ('3', 'CARDINAL'), ('zero', 'CARDINAL')]
# [('last week', 'DATE')]
# [('Reservations', 'ORG'), ('Cajun', 'NORP'), ('100%', 'PERCENT')]
# [('Beef Wellington', 'PERSON')]
# [('Dublin', 'GPE'), ('6pm', 'TIME'), ('2', 'CARDINAL'), ('3', 'CARDINAL'), ('second', 'ORDINAL')]
# [('4-day', 'DATE'), ('Dublin', 'GPE')]
# [('Cajun', 'PERSON')]
# []
# [('First', 'ORDINAL'), ('Dublin', 'GPE'), ('London', 'GPE')]
# []
# [('8.30pm', 'CARDINAL'), ('a week day', 'DATE')]
# [('BYOB!', 'ORG'), ('Christmas', 'DATE')]
# []
# [('Irish', 'NORP')]
# []
# [('Guinness', 'ORG'), ('Cajun', 'NORP'), ('Limited', 'ORG'), ('Tempranillo', 'PERSON'), ('Sean', 'NORP'), ('three', 'CARDINAL'), ('Spotify', 'PRODUCT'), ('Dublin', 'GPE')]
# [('2:30', 'TIME'), ('Christmas', 'DATE'), ('three', 'CARDINAL'), ('Cajun', 'PERSON'), ('third', 'ORDINAL')]
# [('26-30', 'CARDINAL'), ('half', 'CARDINAL')]
# [('30', 'CARDINAL'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('5', 'CARDINAL')]
# [('one', 'CARDINAL'), ('Dublin', 'GPE')]
# [('First', 'ORDINAL'), ('second', 'ORDINAL')]
# []
# []
# [('Dublin', 'GPE'), ('TA', 'GPE'), ('nights 12 months', 'DATE')]
# [('2', 'CARDINAL'), ('two', 'CARDINAL')]
# [('four', 'CARDINAL'), ('Google', 'ORG'), ('100%', 'PERCENT'), ('Ireland', 'GPE')]
# [('the first half hour', 'TIME')]
# [('India', 'GPE'), ('Romania', 'GPE'), ('Germany', 'GPE'), ('a lovely evening', 'TIME')]
# [('Irish', 'NORP')]
# [('one', 'CARDINAL'), ('Portobello', 'ORG'), ('Millstone', 'ORG')]
# [('GF fish & chips', 'ORG'), ('GF mussels & frites', 'ORG'), ('GF garlic', 'PERSON'), ('Dublin', 'GPE')]
# [('13€', 'CARDINAL'), ('7/7', 'CARDINAL'), ('Dublin', 'GPE')]
# [('26.95', 'MONEY')]
# [('12.95', 'MONEY'), ('14.95', 'MONEY')]
# []
# []
# [('16', 'CARDINAL'), ('Mattias Andrea', 'PERSON'), ('Caroline', 'PERSON'), ('Christmas', 'DATE')]
# []
# []
# [('Dublin', 'GPE'), ('Guinness', 'ORG')]
# [('4', 'CARDINAL'), ('2', 'CARDINAL'), ('Europe', 'LOC')]
# []
# [('Pesto', 'PERSON'), ('Chicken', 'PERSON'), ('One', 'CARDINAL')]
# [('Baby Guinness', 'PERSON')]
# [('second', 'ORDINAL')]
# [('Dublin', 'GPE'), ('first', 'ORDINAL')]
# []
# [('1.5h', 'DATE'), ('Irish', 'NORP'), ('Ireland', 'GPE')]
# [('one', 'CARDINAL'), ('2', 'CARDINAL'), ('Yorkshire', 'PERSON'), ('Dublin', 'GPE')]
# [('Guinness', 'ORG'), ('Dublin', 'GPE')]
# [('Friday', 'DATE'), ('night', 'TIME')]
# []
# [('4.3', 'CARDINAL'), ('second', 'ORDINAL'), ('Dublin', 'GPE'), ('Dublin', 'GPE')]
# []
# []
# [('half an hour', 'TIME'), ('Ober', 'LOC'), ('3', 'CARDINAL'), ('1.5 hour', 'TIME'), ('Ober', 'LOC')]
# []
# []
# [('shank', 'ORG')]
# []
# [('one', 'CARDINAL'), ('two', 'CARDINAL')]
# [('Guiness', 'PERSON')]
# [('Dublin', 'GPE')]
# []
# [('1909', 'DATE')]
# [('Friday', 'DATE'), ('evening', 'TIME'), ('two', 'CARDINAL'), ('5', 'CARDINAL'), ('Calamari', 'PERSON'), ('5', 'CARDINAL')]
# [('Dublin', 'GPE')]
# [('first', 'ORDINAL'), ('Ireland', 'GPE'), ('that day', 'DATE'), ('the day', 'DATE')]
# [('afternoon', 'TIME')]
# []
# []
# [('Burger', 'ORG'), ('Wings', 'ORG'), ('Saturday', 'DATE'), ('night', 'TIME')]
# []
# [('our weekend', 'DATE'), ('Dublin', 'GPE'), ('one', 'CARDINAL'), ('Dublin', 'GPE')]
# []
# []
# []
# []
# [('Luigi Malone’s', 'ORG'), ('Dublin', 'GPE'), ('Temple Bar', 'ORG'), ('Luigi’s', 'ORG'), ('Temple Bar', 'ORG'), ('Luigi Malone', 'PERSON')]
# []
# [('Toblerone', 'PRODUCT')]
# [('first', 'ORDINAL'), ('many centuries ago', 'DATE'), ('Google', 'ORG')]
# [('BLUE', 'ORG'), ('Ragu', 'ORG')]
# [('Burrata', 'GPE')]
# [('yesterday', 'DATE'), ('20 minutes', 'TIME'), ('Mozzarella', 'LOC'), ('Bruschetta', 'GPE'), ('2', 'MONEY'), ('10 minutes', 'TIME'), ('30 minutes', 'TIME'), ('75', 'MONEY')]
# [('Luigi Malones', 'PERSON'), ('St. Patrick’s Day', 'GPE'), ('Patrick', 'PERSON'), ('st.', 'GPE'), ('21', 'DATE'), ('American', 'NORP'), ('Dublin', 'GPE'), ('Ireland', 'GPE'), ('Pat', 'PERSON'), ('100%', 'PERCENT'), ('Dublin', 'GPE'), ('Patrick', 'PERSON'), ('day', 'DATE'), ('Nice', 'GPE')]
# [('Pesto Pasta', 'PERSON'), ('Vegetarian', 'NORP'), ('Chicken Fajita and Chicken Burger', 'ORG'), ('Dilek', 'ORG'), ('the Pesto Pasta', 'ORG')]
# []
# [('Dublin', 'GPE')]
# [('Chicken', 'LOC')]
# [('2nd', 'ORDINAL')]
# [('Luigi Malone', 'PERSON'), ('Anne Marie', 'PERSON'), ('5', 'CARDINAL'), ('1', 'CARDINAL'), ('Paulina', 'GPE'), ('1', 'CARDINAL'), ('2.', 'CARDINAL'), ('1', 'CARDINAL')]
# [('3', 'CARDINAL'), ('2', 'CARDINAL')]
# [('Temple Bar', 'ORG')]
# [('yesterday', 'DATE'), ('evening', 'TIME'), ('Saturday', 'DATE'), ('20 seconds', 'TIME'), ('Italian', 'NORP')]
# [('May', 'DATE'), ('Sunday 18th', 'DATE'), ('December', 'DATE'), ('9', 'CARDINAL'), ('only around 3', 'CARDINAL'), ('3', 'CARDINAL'), ('7pm', 'TIME'), ('Irish', 'NORP'), ('3', 'CARDINAL'), ('10', 'CARDINAL'), ('midnight', 'TIME')]
# [('20 minutes', 'TIME')]
# [('Saturday', 'DATE')]
# []
# [('Vincent', 'PERSON')]
# [('last night', 'TIME'), ('Strawberry Daiquiri', 'PERSON'), ('almost zero', 'CARDINAL')]
# [("Luigi Malone's", 'PERSON'), ('more than ten years', 'DATE'), ('One', 'CARDINAL')]
# [('5/5', 'CARDINAL'), ('Location 5/5', 'PRODUCT'), ('Food 4/5', 'CARDINAL'), ('4/5', 'CARDINAL')]
# []
# [('20', 'CARDINAL')]
# [('6', 'CARDINAL'), ('a second hour', 'TIME'), ('25-30 minutes', 'TIME'), ('40 minutes', 'TIME'), ('an hour', 'TIME'), ('one', 'CARDINAL'), ('10 minutes', 'TIME'), ('22:30pm', 'CARDINAL'), ('5', 'CARDINAL')]
# [('Italian', 'NORP')]
# [('about 50 minutes', 'TIME'), ('the day', 'DATE'), ('24 €', 'DATE')]
# [('Carbonara', 'PERSON'), ('Meh', 'PERSON'), ('😏\nVery', 'PERSON')]
# [('Mexican', 'NORP')]
# [('half 12 sunday', 'DATE'), ('all day', 'DATE'), ('Dublin', 'GPE'), ('Dublin', 'GPE')]
# [('25', 'CARDINAL'), ('25', 'CARDINAL'), ('25', 'CARDINAL')]
# [('many years ago', 'DATE'), ('about 6 years', 'DATE')]
# []
# [('2', 'CARDINAL'), ('2', 'CARDINAL')]
# [('Cheeseburger', 'NORP')]
# [('4', 'CARDINAL'), ('Stone', 'ORG'), ('Yummy', 'PERSON'), ('16', 'CARDINAL'), ('Madrid', 'GPE'), ('the day', 'DATE')]
# [('Merlot', 'ORG'), ('🤗', 'ORG')]
# [('10pm', 'TIME'), ('10pm', 'TIME'), ('10pm', 'TIME')]
# [('Chocolate Brownie', 'PERSON'), ('dessert', 'PERSON'), ('lasagne & burrata pasta', 'ORG'), ('only one', 'CARDINAL')]
# [('Ireland', 'GPE'), ('nearly 45 minutes', 'TIME'), ('two hours', 'TIME'), ('about 3 hours', 'TIME')]
# []
# [('2', 'CARDINAL'), ('10€.', 'CARDINAL'), ('Pasta', 'ORG'), ('Pizza, Burgers &', 'ORG')]
# [('the week day', 'DATE')]
# [('Spanish', 'LANGUAGE')]
# [('Snatching', 'GPE'), ('one', 'CARDINAL'), ('Verdict', 'PERSON'), ('Irish', 'NORP'), ('two', 'CARDINAL')]
# [('Temple Bar', 'ORG')]
# [('Temple Bar - very', 'FAC')]
# [('Somebody Feed Phil', 'PERSON'), ('Netflix', 'GPE'), ('One', 'CARDINAL'), ('Dublin', 'GPE'), ('Ireland', 'GPE'), ('Phil Rosenthal', 'PERSON'), ('9:30 pm', 'TIME'), ('Portmarnock', 'GPE'), ('Boxty Sharing Platter', 'PERSON'), ('Gallagher', 'PERSON'), ('Lamb Stew', 'PERSON'), ('Beef & Stout Stew', 'ORG'), ('Traditional Irish Corned Beef', 'EVENT'), ('Sticky Toffee', 'PERSON')]
# [('the day', 'DATE')]
# [('OpenTable', 'PRODUCT')]
# [('the Temple Bar district', 'LOC'), ('Amazing Boxty', 'ORG'), ('Leitrim', 'ORG'), ('Phil', 'PERSON'), ('Phil', 'PERSON')]
# [('Boxty', 'GPE'), ('Mike', 'PERSON'), ('first', 'ORDINAL'), ('first', 'ORDINAL'), ('Dublin', 'GPE')]
# [('Ireland', 'GPE'), ('4days', 'CARDINAL'), ('Irish', 'NORP'), ('Boxty', 'PERSON'), ('Colcannon', 'ORG'), ('Champ', 'ORG'), ('Boxty', 'PERSON'), ('Boxty', 'PERSON'), ('Ireland', 'GPE'), ('🇮', 'CARDINAL')]
# [('tonight', 'TIME'), ('20 years', 'DATE'), ('a fun evening', 'TIME')]
# [('9 pm', 'TIME'), ('2', 'CARDINAL'), ('2', 'CARDINAL'), ('2', 'CARDINAL'), ('Irish', 'NORP'), ('Irish', 'NORP')]
# [('our first night', 'TIME'), ('Dublin', 'GPE'), ('Mike', 'PERSON')]
# [('one', 'CARDINAL'), ('Dublin', 'GPE'), ('TripAdvisor', 'ORG'), ('Irish', 'NORP'), ('Dublin', 'GPE')]
# []
# [('Phil Rosenthal', 'PERSON'), ('Dublin', 'GPE'), ('WOW 🤩', 'ORG')]
# [('Angela', 'PERSON'), ('10/10', 'CARDINAL'), ('Netflix', 'GPE'), ('Ireland', 'GPE'), ('🇮', 'CARDINAL')]
# []
# [('Irish', 'NORP'), ('Irish', 'NORP'), ('Boxty', 'GPE'), ('Dublin', 'GPE')]
# [('first', 'ORDINAL')]
# [('Boxty', 'GPE')]
# [('Dublin', 'GPE')]
# [('Irish', 'NORP'), ('Leitrim', 'ORG'), ('Dublin', 'GPE'), ('Boxties', 'ORG'), ('Ireland', 'GPE')]
# [('Cozy', 'PERSON'), ('Gaelic Boxty', 'PERSON'), ('Michelin', 'PERSON')]
# [("the St. Patrick's", 'ORG'), ('Day Dublin', 'PERSON'), ('Gaelic', 'ORG'), ('Stonewell', 'ORG')]
# [('Thursday', 'DATE')]
# [('Temple Bar', 'FAC')]
# [('today', 'DATE'), ('4', 'CARDINAL'), ('1/3', 'CARDINAL'), ('REALLY', 'ORG'), ('Boxty', 'PERSON')]
# [('Dublin', 'GPE')]
# []
# [('Irish', 'NORP'), ('Mike', 'PERSON')]
# []
# [('Boxty', 'PERSON'), ('first', 'ORDINAL'), ('Jack Smyth', 'PERSON')]
# [('Mike', 'PERSON'), ('last night', 'TIME'), ('Ireland', 'GPE')]
# [('🤯', 'ORG')]
# [('Dublin', 'GPE'), ('Euro', 'WORK_OF_ART')]
# [('Boxty House', 'ORG')]
# [('the weekend', 'DATE')]
# [('3', 'CARDINAL'), ('Lamb Stew', 'PERSON'), ('Dublin Coddle', 'ORG'), ('3', 'CARDINAL'), ('Turkey', 'GPE')]
# [('Vegetarian', 'NORP')]
# [('three', 'CARDINAL'), ('Irish', 'NORP')]
# [('Irish', 'NORP'), ('The Boxty Fish & Chips', 'ORG'), ('The Jack Smyth', 'PERSON'), ('Irish', 'NORP')]
# [('Irish', 'NORP')]
# []
# [('Burger 🍔', 'ORG')]
# []
# [('3', 'CARDINAL')]
# [('The Beef & Stout', 'ORG'), ('3', 'CARDINAL')]
# [('Cons', 'PERSON')]
# []
# [('Gaelic', 'ORG')]
# [('One', 'CARDINAL'), ('Mikado', 'PERSON')]
# []
# [('Dublin', 'GPE'), ('french', 'NORP'), ('asian', 'NORP'), ('one', 'CARDINAL'), ('5', 'CARDINAL'), ('1er', 'ORDINAL'), ('One', 'CARDINAL')]
# [('three-hour', 'TIME')]
# []
# [('Fox', 'PERSON'), ('Michelin', 'PERSON'), ('every penny', 'MONEY')]
# [('Michelin', 'PERSON'), ('Irish', 'NORP'), ('French', 'NORP'), ('2', 'CARDINAL')]
# [('this year', 'DATE')]
# [('Dublin', 'GPE'), ('michellin', 'GPE')]
# [('my first night', 'TIME'), ('Dublin', 'GPE'), ('Cod', 'PERSON'), ('Duck', 'PERSON'), ('Lemon', 'GPE'), ('dessert', 'PERSON'), ('Ambiance', 'GPE'), ('Decor', 'ORG'), ('4/5', 'CARDINAL'), ('Ambiance', 'GPE'), ('3/5', 'CARDINAL'), ('4/5', 'CARDINAL'), ('4/5', 'CARDINAL'), ('5/5', 'CARDINAL')]
# []
# [('two/three', 'CARDINAL')]
# [('Michelin', 'PERSON'), ('Europe', 'LOC')]
# [('Natália', 'GPE')]
# [('Firstly', 'ORDINAL'), ('five', 'CARDINAL'), ('Fox', 'PERSON'), ('Google', 'ORG'), ('6', 'CARDINAL'), ('Fox', 'PERSON'), ('3', 'CARDINAL'), ('Fox', 'PERSON'), ('Suffice', 'ORG'), ('Parnell Square', 'FAC'), ('Michelin Star', 'ORG'), ('Fox', 'PERSON'), ('Fox', 'PERSON')]
# [('only €70', 'MONEY')]
# [('Michelin', 'PERSON')]
# [('40th at the weekend', 'DATE')]
# [('Ireland', 'GPE')]
# [('Dublin', 'GPE'), ('three', 'CARDINAL'), ('Fox', 'PERSON')]
# [('Dublin', 'GPE'), ('10/10', 'CARDINAL'), ('12/10', 'CARDINAL')]
# [('Dublin', 'GPE'), ('Michelin', 'PERSON')]
# [('Fox', 'PERSON')]
# [('Allow', 'PERSON'), ('2 1/2 hours', 'TIME')]
# []
# [('Fox', 'PERSON'), ('four', 'CARDINAL'), ('May', 'DATE')]
# [('One', 'CARDINAL'), ('230', 'MONEY')]
# [('PX', 'ORG')]
# []
# [('Dublin', 'GPE'), ('a weekend', 'DATE'), ('6', 'CARDINAL'), ('Eele', 'PERSON'), ('Guinea Hen and', 'ORG'), ('Carpaccio', 'PRODUCT')]
# [('every month', 'DATE'), ('65€', 'CARDINAL'), ('6', 'CARDINAL')]
# []
# [('12%', 'PERCENT'), ('4', 'CARDINAL'), ('around 500', 'CARDINAL'), ('EUR', 'ORG'), ('around 50', 'CARDINAL'), ('EUR', 'ORG'), ('Dublin', 'GPE'), ('US', 'GPE')]
# []
# [('5', 'CARDINAL'), ('Boris', 'PERSON'), ('Dublin', 'GPE')]
# [('Michelin', 'PERSON'), ('n’t', 'GPE')]
# [('tonight', 'TIME'), ('Fox', 'PERSON'), ('one', 'CARDINAL'), ('next month', 'DATE')]
# [('Bastible', 'ORG'), ('Variety Jones', 'ORG')]
# []
# []
# [('Fox', 'PERSON')]
# [('evening', 'TIME'), ('Michelin', 'PERSON'), ('75 euro', 'QUANTITY')]
# [('3rd', 'ORDINAL'), ('4th', 'ORDINAL'), ('this month', 'DATE'), ('November 2021', 'DATE'), ('Natalia', 'GPE'), ('Fox', 'PERSON')]
# [('one', 'CARDINAL'), ('11', 'CARDINAL'), ('seconds', 'TIME'), ('Fine Wines', 'ORG'), ('the Pinot Noir', 'ORG'), ('Saturday', 'DATE'), ('night', 'TIME'), ('Fox', 'PERSON')]
# [('Home', 'ORG'), ('last week', 'DATE'), ('Parmesan agnoloti', 'PERSON'), ('French', 'NORP'), ('almond', 'ORG')]
# [('First', 'ORDINAL'), ('over 2 hours', 'TIME')]
# [('Fox', 'PERSON'), ('Fox', 'PERSON')]
# [('Truly Michelin', 'PERSON')]
# [('first', 'ORDINAL'), ('Ireland', 'GPE'), ('11', 'CARDINAL'), ('evening', 'TIME'), ('5', 'CARDINAL'), ('5', 'CARDINAL'), ('Fox', 'PERSON')]
# []

# %%
displacy.render(doc, jupyter=True, style='ent')
#Running this code will display a visual representation
#of the named entities detected in the 'article'. Each entity will be highlighted with its respective entity label.
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This place is absolutely outstanding. It was a birthday dinner for my boyfriend and it definitely did not disappoint. The food from start to finish was immaculate, flavors were to die for and fab cocktails too. The service from the moment we walked in was great, as soon as we were through the door there was someone greeting us. The attention and care for their customer service was top quality, they even helped me organize a birthday dessert for him at the end. Highly recommend for a special occasion, with the price range it wouldn't suit a standard date night (for most people).</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Excellent dinner experience in the city center of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dublin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Book in advance is recommended. You can have the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  course meal for a fixed price or a la carte. Highly recommended to take a look at the fine choice of aged meats. Varied and diverse choice of wines</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Outstanding from start to finish!</br></br>Enjoyed a wonderful evening at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fire.
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# Service was top notch in the bar and at our table.</br></br>Food was beautifully cooked and presentation was superb.</br></br>We opted for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  course set menu which offered really good value all round. Some of the dishes carry a supplement (the prawns amd the rib eye steak) but they are worth choosing if you like these!</br></br>If you like cauliflower then the side order of cauliflower is a must!!</br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cocktails were equally beautiful.</br></br>We sat on the terrace and the view of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawson St
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     evening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  closed in was wonderful.</br></br>We look forward to our next visit soon! Thanks to everyone there for a memorable time!</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Called in on a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  without a booking with my daughter. We were accommodated and brought to a terrace table. View was great and staff were excellent. My daughter who can be a tad fussy was thrilled with her food even though it was on a kids menu it looked like a grown up lunch. The food was fresh and tasty toilets were spotless and staff were brilliant. Thank you for making our day</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">We went
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for lunch, food was amazing! The place is incredible and the serve was really good.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Greece
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) served us and he was very very attentive, very good looking at other tables, he said is new but he looked very calm and confident, definitely this is our new fav restaurant</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Such a great experience and the food was of course, outstanding. The building itself was beautiful, a great setting and the inside exactly the same, creating a vibrant yet sophisticated atmosphere.</br>All our food was exceptional and the service matched at every point from the moment you walk in. Very tentative. Unfortunately towards
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of the night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , this did die off with staff members finishing their shifts and we had to wait a long time for someone to ask and then indeed follow up on the dessert order and the bill.</br>However I was pleasantly surprised when
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  small complimentary puddings were delivered for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  members of the party who we’re celebrating their birthday. Great little touch.</br>Price is hight but not extortionate for a restaurant of this quality. You get what you pay for.</br>Overall a must if your visiting this fantastic city.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Amazing place. Since the receptionists who receive me whit large smiles to the waiter who help us and guided to order the best plate. My special thanks to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0

# %%
import re
def preprocessor(text):
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)',
                           text)
    text = (re.sub('[\W]+', ' ', text.lower()) +
            ' '.join(emoticons).replace('-', ''))
    return text

# %%
preprocessor(df.loc[0, 'review_text'][-50:])
# Out:
# 'dn t suit a standard date night for most people '

# %%
df['review_text'] = df['review_text'].apply(preprocessor)

# %%
df['review_text'] = df['review_text'].astype(str)
#df['review_text'] = df['review_text'].str.lower()

# %%
stemmer = PorterStemmer()
def stem_words(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])
df['review_text'] = df['review_text'].apply(lambda x: stem_words(x))

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return ' '.join([lemmatizer.lemmatize(word) for word in text.split()])
df["review_text"] = df["review_text"].apply(lambda text: lemmatize_words(text))

# %%
df['review_text'].head()
# Out:
# 0    thi place is absolut outstand it wa a birthday...
# 1    excel dinner experi in the citi center of dubl...
# 2    outstand from start to finish enjoy a wonder e...
# 3    call in on a saturday without a book with my d...
# 4    we went today for lunch food wa amaz the place...
# Name: review_text, dtype: object

# %%
#df.to_csv('Preprocessed Fake Reviews Detection Dataset.csv')

# %%
plt.figure(figsize=(8,10))
sns.countplot(y='review_text',data=df,order=df.review_text.value_counts().iloc[:10].index)
# Out:
# <Axes: xlabel='count', ylabel='review_text'>

# %%
#after removing punction, readding it in as indicator
df['review_text'].replace({'!': ' exclamation ','?': ' question ',
                           '\'' : ' quotation ','\'': 'quotation'},inplace=True)

# %%
#repeat for positive and negative ratings
consolidated=' '.join(word for word in df['review_text'][df['rating']>4.5].astype(str))
wordCloud=WordCloud(width=1600,height=800,random_state=21,max_font_size=110)
plt.figure(figsize=(15,10))
plt.imshow(wordCloud.generate(consolidated),interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#repeat for positive and negative ratings
consolidated=' '.join(word for word in df['review_text'][df['rating']<4].astype(str))
wordCloud=WordCloud(width=1600,height=800,random_state=21,max_font_size=110)
plt.figure(figsize=(15,10))
plt.imshow(wordCloud.generate(consolidated),interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
nltk.download('punkt')

# %%
import string
from nltk import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud

def clean(text):
    text=word_tokenize(text)
    text=[word.lower() for word in text if word.isalpha()]
    punct=str.maketrans('','', string.punctuation)
    text=[word.translate(punct) for word in text]
    #text =[word for word in text if not word in stopwords]
    return text
df['review_text']=df['review_text'].apply(clean)

# %%
df['tokenized'] = df.apply(lambda x: clean(x['review_text']), axis=1)
df.head()

# %%
from collections import Counter

def counter(text):
    cnt=Counter()
    for msgs in text:
        for msg in msgs:
            cnt[msg] += 1
    return cnt

text_cnt=counter(df['review_text'])

# %%
text_cnt.most_common(10)
# Out:
# [("'", 130790),
#  (',', 64395),
#  (' ', 64395),
#  ('e', 30557),
#  ('t', 24512),
#  ('a', 23615),
#  ('i', 20012),
#  ('o', 19765),
#  ('r', 17113),
#  ('n', 14618)]

# %%
common_words= text_cnt.most_common(30)
common_words=pd.DataFrame(common_words, columns=['Words','Counts'])
plt.figure(figsize=(8,10))
sns.barplot(y='Words', x='Counts', data=common_words)

# %%
from nltk.tokenize import word_tokenize 
nltk.download('punkt')
from nltk.probability import FreqDist
from nltk import sent_tokenize, word_tokenize as word_tokenize

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
reviewText = df['review_text'].astype(str)

# %%
reviewText = reviewText.apply(word_tokenize)
reviewText.head()
# Out:
# 0    [This, place, is, absolutely, outstanding, ., ...
# 1    [Excellent, dinner, experience, in, the, city,...
# 2    [Outstanding, from, start, to, finish, !, Enjo...
# 3    [Called, in, on, a, Saturday, without, a, book...
# 4    [We, went, today, for, lunch, ,, food, was, am...
# Name: review_text, dtype: object

# %%
fdist = FreqDist(reviewText[6])
fdist
# Out:
# FreqDist({'.': 8, 'the': 6, 'to': 6, 'and': 4, ',': 3, 'a': 3, 'will': 3, 'place': 2, 'who': 2, 'me': 2, ...})

# %%
reviewText.head()
# Out:
# 0    [This, place, is, absolutely, outstanding, ., ...
# 1    [Excellent, dinner, experience, in, the, city,...
# 2    [Outstanding, from, start, to, finish, !, Enjo...
# 3    [Called, in, on, a, Saturday, without, a, book...
# 4    [We, went, today, for, lunch, ,, food, was, am...
# Name: review_text, dtype: object

# %%
#positive speech tagging
reviewText = df['review_text'].astype(str)
nltk.download('averaged_perceptron_tagger')
text = reviewText[8]
word_tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(word_tokens)
for token in text:
    print(nltk.pos_tag([token]))
tig= nltk.pos_tag([token])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('G', 'NN')]
# [('r', 'NN')]
# [('e', 'NN')]
# [('a', 'DT')]
# [('t', 'NN')]
# [(' ', 'NN')]
# [('f', 'NN')]
# [('o', 'NN')]
# [('o', 'NN')]
# [('d', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('n', 'NN')]
# [('d', 'NN')]
# [(' ', 'NN')]
# [('v', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('y', 'NN')]
# [(' ', 'NN')]
# [('g', 'NN')]
# [('o', 'NN')]
# [('o', 'NN')]
# [('d', 'NN')]
# [(' ', 'NN')]
# [('s', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('v', 'NN')]
# [('i', 'NN')]
# [('c', 'NNS')]
# [('e', 'NN')]
# [('.', '.')]
# [(' ', 'NN')]
# [('I', 'PRP')]
# [('t', 'NN')]
# [("'", "''")]
# [('s', 'NN')]
# [(' ', 'NN')]
# [('o', 'NN')]
# [('n', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('l', 'NN')]
# [('i', 'NN')]
# [('k', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('h', 'NN')]
# [('i', 'NN')]
# [('g', 'NN')]
# [('h', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [(' ', 'NN')]
# [('L', 'NN')]
# [('e', 'NN')]
# [('v', 'NN')]
# [('e', 'NN')]
# [('l', 'NN')]
# [(' ', 'NN')]
# [('o', 'NN')]
# [('n', 'NN')]
# [(' ', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('v', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('a', 'DT')]
# [('g', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('i', 'NN')]
# [('n', 'NN')]
# [(' ', 'NN')]
# [('D', 'NN')]
# [('u', 'NN')]
# [('b', 'NN')]
# [('l', 'NN')]
# [('i', 'NN')]
# [('n', 'NN')]
# [('.', '.')]
# [('\n', 'NN')]
# [('\n', 'NN')]
# [('W', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('w', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('6', 'CD')]
# [(' ', 'NN')]
# [('p', 'NN')]
# [('e', 'NN')]
# [('o', 'NN')]
# [('p', 'NN')]
# [('l', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('w', 'NN')]
# [('i', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [(' ', 'NN')]
# [('b', 'NN')]
# [('a', 'DT')]
# [('b', 'NN')]
# [('y', 'NN')]
# [('.', '.')]
# [(' ', 'NN')]
# [('W', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('h', 'NN')]
# [('a', 'DT')]
# [('v', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('S', 'NN')]
# [('a', 'DT')]
# [('t', 'NN')]
# [('u', 'NN')]
# [('r', 'NN')]
# [('d', 'NN')]
# [('a', 'DT')]
# [('y', 'NN')]
# [(' ', 'NN')]
# [('m', 'NN')]
# [('e', 'NN')]
# [('n', 'NN')]
# [('u', 'NN')]
# [(' ', 'NN')]
# [('o', 'NN')]
# [('f', 'NN')]
# [(' ', 'NN')]
# [('4', 'CD')]
# [('0', 'CD')]
# [('€', 'NN')]
# [(' ', 'NN')]
# [('w', 'NN')]
# [('i', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [(' ', 'NN')]
# [('3', 'CD')]
# [(' ', 'NN')]
# [('p', 'NN')]
# [('l', 'NN')]
# [('a', 'DT')]
# [('t', 'NN')]
# [('e', 'NN')]
# [('s', 'NN')]
# [(',', ',')]
# [(' ', 'NN')]
# [('s', 'NN')]
# [('t', 'NN')]
# [('a', 'DT')]
# [('r', 'NN')]
# [('t', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [(',', ',')]
# [(' ', 'NN')]
# [('m', 'NN')]
# [('a', 'DT')]
# [('i', 'NN')]
# [('n', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('n', 'NN')]
# [('d', 'NN')]
# [(' ', 'NN')]
# [('d', 'NN')]
# [('e', 'NN')]
# [('s', 'NN')]
# [('s', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('t', 'NN')]
# [('.', '.')]
# [(' ', 'NN')]
# [('+', 'NN')]
# [('1', 'CD')]
# [('5', 'CD')]
# [('€', 'NN')]
# [(' ', 'NN')]
# [('f', 'NN')]
# [('o', 'NN')]
# [('r', 'NN')]
# [(' ', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('R', 'NN')]
# [('i', 'NN')]
# [('b', 'NN')]
# [(' ', 'NN')]
# [('E', 'NN')]
# [('y', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('b', 'NN')]
# [('u', 'NN')]
# [('t', 'NN')]
# [(' ', 'NN')]
# [('i', 'NN')]
# [('t', 'NN')]
# [("'", "''")]
# [('s', 'NN')]
# [(' ', 'NN')]
# [('w', 'NN')]
# [('o', 'NN')]
# [('r', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [(' ', 'NN')]
# [('i', 'NN')]
# [('t', 'NN')]
# [('.', '.')]
# [('\n', 'NN')]
# [('\n', 'NN')]
# [('T', 'NN')]
# [('h', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('s', 'NN')]
# [('e', 'NN')]
# [('r', 'NN')]
# [('v', 'NN')]
# [('i', 'NN')]
# [('c', 'NNS')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('r', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('w', 'NN')]
# [('a', 'DT')]
# [('r', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('o', 'NN')]
# [('f', 'NN')]
# [(' ', 'NN')]
# [('y', 'NN')]
# [('o', 'NN')]
# [('u', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('n', 'NN')]
# [('d', 'NN')]
# [(' ', 'NN')]
# [('t', 'NN')]
# [('a', 'DT')]
# [('k', 'NN')]
# [('i', 'NN')]
# [('n', 'NN')]
# [('g', 'NN')]
# [(' ', 'NN')]
# [('c', 'NNS')]
# [('a', 'DT')]
# [('r', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('o', 'NN')]
# [('f', 'NN')]
# [(' ', 'NN')]
# [('y', 'NN')]
# [('o', 'NN')]
# [('u', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('n', 'NN')]
# [('d', 'NN')]
# [(' ', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [('a', 'DT')]
# [('t', 'NN')]
# [(' ', 'NN')]
# [('y', 'NN')]
# [('o', 'NN')]
# [('u', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('r', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('n', 'NN')]
# [('o', 'NN')]
# [('t', 'NN')]
# [(' ', 'NN')]
# [('m', 'NN')]
# [('i', 'NN')]
# [('s', 'NN')]
# [('s', 'NN')]
# [('i', 'NN')]
# [('n', 'NN')]
# [('g', 'NN')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [('n', 'NN')]
# [('y', 'NN')]
# [('t', 'NN')]
# [('h', 'NN')]
# [('i', 'NN')]
# [('n', 'NN')]
# [('g', 'NN')]
# [('.', '.')]
# [('\n', 'NN')]
# [('\n', 'NN')]
# [('T', 'NN')]
# [('h', 'NN')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('p', 'NN')]
# [('l', 'NN')]
# [('a', 'DT')]
# [('c', 'NNS')]
# [('e', 'NN')]
# [(' ', 'NN')]
# [('b', 'NN')]
# [('e', 'NN')]
# [('a', 'DT')]
# [('u', 'NN')]
# [('t', 'NN')]
# [('i', 'NN')]
# [('f', 'NN')]
# [('u', 'NN')]
# [('l', 'NN')]
# [('.', '.')]

# %%
#named entity recognition, system identifies which word is a person’s name, location, etc.
from nltk import ne_chunk# tokenize and POS Tagging before doing chunk
nltk.download('maxent_ne_chunker')
nltk.download('words')
#importing chunk library from nltk
#text = reviewText[8]
#token = word_tokenize(text)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
pip install svgling
# Out:
# Requirement already satisfied: svgling in c:\users\quain\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: svgwrite in c:\users\quain\anaconda3\lib\site-packages (from svgling) (1.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#tags = nltk.pos_tag(token)
#chunking picking up individual pieces of info and grouping into bigger pieces ie grouping words/tokens into chunks
chunk = ne_chunk(tig)
chunk
# Out:
# Tree('S', [('.', '.')])

# %%
reg = "NP: {<DT>?<JJ>*<NN>}"
a = nltk.RegexpParser(reg)
result = a.parse(tig)
print(result)
# Out:
# (S ./.)

# %%
pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in c:\users\quain\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\quain\anaconda3\lib\site-packages (from vaderSentiment) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\quain\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\quain\anaconda3\lib\site-packages (from requests->vaderSentiment) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\quain\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\quain\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#pip install pandarallel
import nltk
nltk.download('vader_lexicon')
df['review_text'].astype(str)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\quain\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# 0      This place is absolutely outstanding. It was a...
# 1      Excellent dinner experience in the city center...
# 2      Outstanding from start to finish!\n\nEnjoyed a...
# 3      Called in on a Saturday without a booking with...
# 4      We went today for lunch, food was amazing! The...
#                              ...
# 995    First time visiting and it was an excellent ex...
# 996    Mr. Fox have been the best choice that I made ...
# 997    Words cannot describe the impeccable experienc...
# 998    That was a first restaurant we went after a lo...
# 999          Lovely place!  Very private and great food!
# Name: review_text, Length: 1000, dtype: object

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sent_i = SentimentIntensityAnalyzer()

def vadar_sentiment(text):
    """ Calculate and return the nltk vadar (lexicon method) sentiment """
    return sent_i.polarity_scores(text)['compound']

# create new column for vadar compound sentiment score
df['vadar compound'] = df['review_text'].apply(vadar_sentiment)

def categorise_sentiment(sentiment, neg_threshold=-0.05, pos_threshold=0.05):
    """ categorise the sentiment value as positive (1), negative (-1) 
        or neutral (0) based on given thresholds """
    if sentiment < neg_threshold:
        label = 'negative'
    elif sentiment > pos_threshold:
        label = 'positive'
    else:
        label = 'neutral'
    return label

# new col with vadar sentiment label based on vadar compound score
df['vadar sentiment'] = df['vadar compound'].apply(categorise_sentiment)

# %%
df.head()
# Out:
#                 query                   name  \
# 0  restaurant, dublin  FIRE Steakhouse & Bar
# 1  restaurant, dublin  FIRE Steakhouse & Bar
# 2  restaurant, dublin  FIRE Steakhouse & Bar
# 3  restaurant, dublin  FIRE Steakhouse & Bar
# 4  restaurant, dublin  FIRE Steakhouse & Bar
#
#                                google_id                     place_id  \
# 0  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 1  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 2  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 3  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
# 4  0x48670e9baf2ed897:0xa78bc9f5604e6175  ChIJl9gur5sOZ0gRdWFOYPXJi6c
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/FIRE+Steakho...
# 1  https://www.google.com/maps/place/FIRE+Steakho...
# 2  https://www.google.com/maps/place/FIRE+Steakho...
# 3  https://www.google.com/maps/place/FIRE+Steakho...
# 4  https://www.google.com/maps/place/FIRE+Steakho...
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
# 2  https://search.google.com/local/reviews?placei...
# 3  https://search.google.com/local/reviews?placei...
# 4  https://search.google.com/local/reviews?placei...
#
#                                    reviews_per_score  reviews  rating  \
# 0  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 1  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 2  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 3  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
# 4  {"1": 95, "2": 101, "3": 250, "4": 656, "5": 1...     2951     4.4
#
#                               review_id  ... owner_answer_timestamp  \
# 0   ChZDSUhNMG9nS0VJQ0FnSURScjhhVlNBEAE  ...                    NaN
# 1  ChdDSUhNMG9nS0VJQ0FnSUNKdnJLY3RnRRAB  ...                    NaN
# 2   ChZDSUhNMG9nS0VJQ0FnSURoczRuWU1BEAE  ...                    NaN
# 3  ChdDSUhNMG9nS0VJQ0FnSUNKLXNhMnpRRRAB  ...                    NaN
# 4  ChdDSUhNMG9nS0VJQ0FnSUR4OGFfVTNnRRAB  ...                    NaN
#
#   owner_answer_timestamp_datetime_utc  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                          review_link review_rating  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 1  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 2  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 3  https://www.google.com/maps/reviews/data=!4m8!...           5.0
# 4  https://www.google.com/maps/reviews/data=!4m8!...           5.0
#
#   review_timestamp  review_datetime_utc review_likes    reviews_id  \
# 0     1.683401e+09     05/06/2023 19:20          0.0 -6.373780e+18
# 1     1.687931e+09  06/28/2023 05:41:44          1.0 -6.373780e+18
# 2     1.679049e+09  03/17/2023 10:27:11          1.0 -6.373780e+18
# 3     1.687723e+09  06/25/2023 19:54:18          0.0 -6.373780e+18
# 4     1.686415e+09     06/10/2023 16:43          0.0 -6.373780e+18
#
#    vadar compound vadar sentiment
# 0          0.9745        positive
# 1          0.7964        positive
# 2          0.9897        positive
# 3          0.9674        positive
# 4          0.9702        positive
#
# [5 rows x 28 columns]

# %%
#generate summary statistics
df[['vadar compound']].describe()
# Out:
#        vadar compound
# count     1000.000000
# mean         0.781704
# std          0.393886
# min         -0.972300
# 25%          0.817275
# 50%          0.927700
# 75%          0.967825
# max          0.999300

# %%
#generate mean of sentiment_score by period
dfg = df.groupby(['review_rating'])['vadar compound'].mean()
#create a bar plot
dfg.plot(kind='bar', title='Sentiment Score', ylabel='Mean Sentiment Score',
         xlabel='Period', figsize=(6, 5))
# Out:
# <Axes: title={'center': 'Sentiment Score'}, xlabel='Period', ylabel='Mean Sentiment Score'>

# %%
df['vadar sentiment'].value_counts()
# Out:
# positive    930
# negative     62
# neutral       8
# Name: vadar sentiment, dtype: int64

# %%
positive_consolidated=' '.join(word for word in df['review_text'][df['vadar sentiment']=='positive'].astype(str))
wordCloud=WordCloud(width=1600,height=800,random_state=21,max_font_size=110)
plt.figure(figsize=(15,10))
plt.imshow(wordCloud.generate(positive_consolidated),interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
negative_consolidated=' '.join(word for word in df['review_text'][df['vadar sentiment']=='negative'].astype(str))
wordCloud=WordCloud(width=1600,height=800,random_state=21,max_font_size=110)
plt.figure(figsize=(15,10))
plt.imshow(wordCloud.generate(negative_consolidated),interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Converting text into Vectors
#TF-IDF calculates that how relevant a word in a series or corpus is to a text. The meaning increases proportionally
#to the number of times in the text a word appears but is compensated by the word frequency in the corpus (data-set)
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(max_features=2500)
X = cv.fit_transform(df['review_text'] ).toarray()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report

# %%
dfNew = df[['review_text','vadar sentiment']]
dfNew.head()
# Out:
#                                          review_text vadar sentiment
# 0  This place is absolutely outstanding. It was a...        positive
# 1  Excellent dinner experience in the city center...        positive
# 2  Outstanding from start to finish!\n\nEnjoyed a...        positive
# 3  Called in on a Saturday without a booking with...        positive
# 4  We went today for lunch, food was amazing! The...        positive

# %%
# random split train and test data
index = df.index
df['random_number'] = np.random.randn(len(index))
train = df[df['random_number'] <= 0.8]
test = df[df['random_number'] > 0.8]

# %%
#Predicting sentiment

#analysis and vectorization is done. We can now explore any machine learning model to train the data. But before that 
#perform the train-test split.
from sklearn.model_selection import train_test_split

# count vectorizer:
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(token_pattern=r'\b\w+\b')
train_matrix = vectorizer.fit_transform(train['review_text'])
test_matrix = vectorizer.transform(test['review_text'])

# %%
from sklearn.linear_model import LogisticRegression
 
lr = LogisticRegression(solver='lbfgs', max_iter=6000)

# %%
X_train = train_matrix
X_test = test_matrix
y_train = train['sentiment']
y_test = test['sentiment']

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean=False)
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=6000)

# %%
predictions = lr.predict(X_test)
print(predictions)
# Out:
# ['positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive' 'positive' 'positive' 'positive' 'positive' 'positive'
#  'positive']

# %%
# see the confusion matrix for the results.
from sklearn.metrics import confusion_matrix,classification_report
from sklearn import metrics
new = np.asarray(y_test)
confusion_matrix(predictions,y_test)
# Out:
# array([[  0,   0,   0],
#        [  0,   0,   0],
#        [ 13,   2, 190]], dtype=int64)

# %%
print(classification_report(predictions,y_test))
#no feature extraction or much preprocessing.
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         0
#      neutral       0.00      0.00      0.00         0
#     positive       1.00      0.93      0.96       205
#
#     accuracy                           0.93       205
#    macro avg       0.33      0.31      0.32       205
# weighted avg       1.00      0.93      0.96       205

# %%
#df_processed['clean_month']= np.where(df_processed['month1']>=1,df_processed['month1'],df_processed['month2'])
#df_processed.drop(columns=['month1',"month2"], inplace=True)

# %%
df['review_count']=df['author_title'].value_counts()#reviewers submitting >1 review
x=review_count.value_counts()
x
# Out:
# 1    904
# 2     40
# 3      4
# 4      1
# Name: author_title, dtype: int64

# %%
df['author_id'].value_counts()
# Out:
# 1.173140e+20    4
# 1.008330e+20    4
# 1.006150e+20    3
# 1.055890e+20    3
# 1.166680e+20    3
#                ..
# 1.164410e+20    1
# 1.067010e+20    1
# 1.115980e+20    1
# 1.029050e+20    1
# 1.024060e+20    1
# Name: author_id, Length: 917, dtype: int64

# %%
df['name'].value_counts()
# Out:
# FIRE Steakhouse & Bar                           50
# NoLIta                                          50
# Gallaghers Boxty House                          50
# Luigi Malones Dublin                            50
# The Millstone Restaurant                        50
# The Vintage Kitchen                             50
# Chapter One Restaurant                          50
# FX Buckley Steakhouse Crow Street               50
# The Winding Stair                               50
# Sophie’s                                        50
# Flanagan's Bar & Restaurant                     50
# Las Tapas De Lola                               50
# Old Mill Restaurant                             50
# SOLE Seafood & Grill                            50
# The Church Café, Late Bar & Restaurant          50
# Brasserie Sixty6 Restaurant                     50
# The Market Bar Restaurant                       50
# Fade Street Social Restaurant & Cocktail Bar    50
# The Ivy Dublin                                  50
# Mr Fox                                          50
# Name: name, dtype: int64

# %%
#rule 1 where reviewer has >1 review for same place
df['rule1'] = np.nan#adding additional column
rule1_df = df[["name", 'author_title', "author_id",'place_id','review_count','rule1']]
#agg_rule1_df.head()
#rule1_df .groupby(["author_title"]).count().sort_values(["name"], 
                                            #ascending=False).rename(columns={"accident" : "Sum of accidents"}).reset_index()

rule1_df.head()
# Out:
#                     name                   author_title     author_id  \
# 0  FIRE Steakhouse & Bar                 Leahh Thompson  1.010810e+20
# 1  FIRE Steakhouse & Bar                    Rui Saraiva  1.105680e+20
# 2  FIRE Steakhouse & Bar  Bastable-Warren Irish-Dancers  1.149300e+20
# 3  FIRE Steakhouse & Bar                  Laura Vaughan  1.072940e+20
# 4  FIRE Steakhouse & Bar                 Adriana Tonito  1.067170e+20
#
#                       place_id  review_count  rule1
# 0  ChIJl9gur5sOZ0gRdWFOYPXJi6c           NaN    NaN
# 1  ChIJl9gur5sOZ0gRdWFOYPXJi6c           NaN    NaN
# 2  ChIJl9gur5sOZ0gRdWFOYPXJi6c           NaN    NaN
# 3  ChIJl9gur5sOZ0gRdWFOYPXJi6c           NaN    NaN
# 4  ChIJl9gur5sOZ0gRdWFOYPXJi6c           NaN    NaN

# %%
# Get unique place names from the dataframe
unique_names = df['name'].unique()

# Create an empty list to store the results
results = []

# Iterate over unique place names
for name in unique_names:
    # Filter the dataframe for the current place name
    subset = df[df['name'] == name]
    
    # Get the unique author IDs for the current place name
    unique_author_ids = subset['author_id'].unique()
    
    # Check if the reviews are done by the corresponding author ID
    reviews_by_author_id = subset['author_id'].equals(subset['name'])
    
    # Append the result to the list
    results.append({'name': name, 'reviews_by_author_id': reviews_by_author_id})

# Create a new dataframe from the results list
results_df = pd.DataFrame(results)

# Display the resulting dataframe
print(results_df)
# Out:
#                                             name  reviews_by_author_id
# 0                          FIRE Steakhouse & Bar                 False
# 1                                         NoLIta                 False
# 2                                 The Ivy Dublin                 False
# 3   Fade Street Social Restaurant & Cocktail Bar                 False
# 4                      The Market Bar Restaurant                 False
# 5                    Brasserie Sixty6 Restaurant                 False
# 6         The Church Café, Late Bar & Restaurant                 False
# 7                           SOLE Seafood & Grill                 False
# 8                            Old Mill Restaurant                 False
# 9                              Las Tapas De Lola                 False
# 10                   Flanagan's Bar & Restaurant                 False
# 11                                      Sophie’s                 False
# 12                             The Winding Stair                 False
# 13             FX Buckley Steakhouse Crow Street                 False
# 14                        Chapter One Restaurant                 False
# 15                           The Vintage Kitchen                 False
# 16                      The Millstone Restaurant                 False
# 17                          Luigi Malones Dublin                 False
# 18                        Gallaghers Boxty House                 False
# 19                                        Mr Fox                 False

# %%
# Calculate the count of reviews per author_id
reviews_per_author = df.groupby('author_title')['review_text'].count().reset_index()
reviews_per_author = reviews_per_author.rename(columns={'review_text': 'count of reviews'})

# Calculate the count of unique names of places reviewed per author_id
places_per_author = df.groupby('author_title')['name'].nunique().reset_index()
places_per_author = places_per_author.rename(columns={'name': 'count of names of places reviewed'})

# Merge the two dataframes on 'author_id'
new_dataset = pd.merge(reviews_per_author, places_per_author, on='author_title')
#The for loop iterates over the rows of the new_dataset dataframe using the iterrows() method. Inside the loop, we
#compare the 'count of names of places reviewed' with the 'count of reviews' for each row. 
#If the condition row['count of names of places reviewed'] < row['count of reviews'], there maybe be multiple reviews for
#same place
 #Add 'check 1' column using if-else statements
new_dataset['check 1'] = 0
for index, row in new_dataset.iterrows():
    if row['count of names of places reviewed'] < row['count of reviews']:
        new_dataset.at[index, 'check 1'] = 1

# Add 'check 2' column using if-else statements, check if this person submits>1 review
new_dataset['check 2'] = 0
for index, row in new_dataset.iterrows():
    if row['count of reviews'] > 1:
        new_dataset.at[index, 'check 2'] = 1

        
# Display the resulting dataset
print(new_dataset)
# Out:
#   Cell In[183], line 3
#     reviews_per_author = reviews_per_author.rename(columns={'review_text': 'count of reviews','vadar sentiment','vadar compound'})
#                                                                                                               ^
# SyntaxError: ':' expected after dictionary key

# %%
print(new_dataset['check 1'].unique())
# Out:
# [0]

# %%
#df_processed['reg_year'],df_processed['reg_county1'],df_processed['reg_num'] = df_processed['car_reg'].str.split

# %%
def rule_based_classification(rule1_df):
    categories = []
    for i in range(len(rule1_df)):
        if rule1_df[i]['author_id'] > 2 and rule1_df[i]['name'] > 2:
            categories.append("Category 1")
        elif rule1_df[i][author_id] > 2 or rule1_df[i]['name'] > 2:
            categories.append("Category 2")
        else:
            categories.append("Unclassified")
    
    return categories
rule_based_classification(rule1_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[126], line 12
#       9             categories.append("Unclassified")
#      11     return categories
# ---> 12 rule_based_classification(rule1_df)
#
# Cell In[126], line 4, in rule_based_classification(rule1_df)
#       2 categories = []
#       3 for i in range(len(rule1_df)):
# ----> 4     if rule1_df[i]['author_id'] > 2 and rule1_df[i]['name'] > 2:
#       5         categories.append("Category 1")
#       6     elif rule1_df[i][author_id] > 2 or rule1_df[i]['name'] > 2:
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
rule1_df.head()
# Out:
#                     name                   author_title     author_id  \
# 0  FIRE Steakhouse & Bar                 Leahh Thompson  1.010810e+20
# 1  FIRE Steakhouse & Bar                    Rui Saraiva  1.105680e+20
# 2  FIRE Steakhouse & Bar  Bastable-Warren Irish-Dancers  1.149300e+20
# 3  FIRE Steakhouse & Bar                  Laura Vaughan  1.072940e+20
# 4  FIRE Steakhouse & Bar                 Adriana Tonito  1.067170e+20
#
#                       place_id  rule1
# 0  ChIJl9gur5sOZ0gRdWFOYPXJi6c    NaN
# 1  ChIJl9gur5sOZ0gRdWFOYPXJi6c    NaN
# 2  ChIJl9gur5sOZ0gRdWFOYPXJi6c    NaN
# 3  ChIJl9gur5sOZ0gRdWFOYPXJi6c    NaN
# 4  ChIJl9gur5sOZ0gRdWFOYPXJi6c    NaN
